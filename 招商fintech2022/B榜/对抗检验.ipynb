# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error, log_loss
pd.options.display.precision = 15
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor, CatBoostClassifier
import time
import datetime
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn import linear_model
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import json
# %matplotlib inline

# %env JOBLIB_TEMP_FOLDER=/tmp
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
# 对抗检验
out_path = './output/'
train_path = './data/train_fea_genb4.csv'
test_path = './data/test_B_fea_genb4.csv'
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
print(train.shape,test.shape)
feas = list(train.columns)[2:]
print(len(feas))
cat_cols = ['MON_12_CUST_CNT_PTY_ID','AI_STAR_SCO','WTHR_OPN_ONL_ICO',
'SHH_BCK','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU'] 

for col in cat_cols:
    if col in train.columns:
        le = LabelEncoder()
        le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
        train[col] = le.transform(list(train[col].astype(str).values))
        test[col] = le.transform(list(test[col].astype(str).values))  
X_train = train[feas]
X_test = test[feas]

features = X_train.columns.tolist()
X_train['is_train'] = 1
X_test['is_train'] = 0
data = pd.concat([X_train, X_test], axis =0, ignore_index=True)
train_data, test_data = train_test_split(data, test_size=0.33, random_state=42, shuffle=True)
train_y = train_data['is_train'].values
test_y = test_data['is_train'].values
del train_data['is_train'], test_data['is_train']

importance_result = pd.DataFrame(index=train_data.columns,columns=['cal_auc'])
for i in tqdm(features):
    clf = lgb.LGBMClassifier(
        random_state=47,
        max_depth=2,
        metric='auc',
        n_estimators=1000,
        importance_type='gain'
    )
    clf.fit(
        np.array(train_data[i]).reshape(-1,1),
        train_y,
        eval_set=[(np.array(test_data[i]).reshape(-1,1),test_y)],
        early_stopping_rounds=200,
        verbose=0)
    temp_pred = clf.predict_proba(np.array(test_data[i]).reshape(-1,1))[:,1]
    auc_score = roc_auc_score(test_y,temp_pred)
    importance_result.loc[i,'cal_auc'] = auc_score
    
sorted_impor_fea = importance_result.sort_values('cal_auc', ascending=False)
sorted_impor_fea
# Out:
# (40000, 255) (12000, 255)
# 253
# 100%|██████████| 253/253 [01:12<00:00,  3.51it/s]
#                                                               cal_auc
# PUB_TO_PRV_TRX_AMT_CUR_YEAR                         0.628118694499385
# corr_CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT_LAST_12_M...  0.626834610559427
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_LAST_12_...  0.626591961259377
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_rate         0.626128100305504
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_LAST_12_...  0.626128100305504
# ...                                                               ...
# hand_CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT_CUR_MON_E...  0.498256171755625
# hand_MON_12_EXT_SAM_AMT_MON_12_EXT_SAM_NM_TRSF_...  0.497757697935448
# hand_MON_12_EXT_SAM_TRSF_IN_AMT_MON_12_EXT_SAM_...  0.496822713636679
# hand_MON_12_ACT_IN_50_UP_CNT_PTY_QTY_MON_12_ACT...  0.496624279481972
# hand_MON_6_50_UP_ENTR_ACT_CNT_MON_6_50_UP_LVE_A...  0.490494209786903
#
# [253 rows x 1 columns]

# %%
sorted_impor_fea.head()
# Out:
#                                                               cal_auc
# PUB_TO_PRV_TRX_AMT_CUR_YEAR                         0.628118694499385
# corr_CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT_LAST_12_M...  0.626834610559427
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_LAST_12_...  0.626591961259377
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_rate         0.626128100305504
# corr_CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT_LAST_12_...  0.626128100305504

# %%
features = list(sorted_impor_fea.index)[80:]# 40 /80
print(len(features))
# Out:
# 173

# %%
out_path = './output/'
train_path = './data/train_fea_genb4.csv'
test_path = './data/test_B_fea_genb4.csv'

# %%
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
print(train.shape,test.shape)
# Out:
# (40000, 255) (12000, 255)

# %%
train = train[['CUST_UID','LABEL'] + features]
test = test[['CUST_UID'] + features]
print(train.shape,test.shape)
# Out:
# (40000, 175) (12000, 174)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage(deep=True).sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                c_prec = df[col].apply(lambda x: np.finfo(x).precision).max()
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max and c_prec == np.finfo(np.float32).precision:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage(deep=True).sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df
    
def fast_auc(y_true, y_prob):
    """
    fast roc_auc computation: https://www.kaggle.com/c/microsoft-malware-prediction/discussion/76013
    """
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    nfalse = 0
    auc = 0
    n = len(y_true)
    for i in range(n):
        y_i = y_true[i]
        nfalse += (1 - y_i)
        auc += y_i * nfalse
    auc /= (nfalse * (n - nfalse))
    return auc


def eval_auc(y_true, y_pred):
    """
    Fast auc eval function for lgb.
    """
    return 'auc', fast_auc(y_true, y_pred), True


def group_mean_log_mae(y_true, y_pred, types, floor=1e-9):
    """
    Fast metric computation for this competition: https://www.kaggle.com/c/champs-scalar-coupling
    Code is from this kernel: https://www.kaggle.com/uberkinder/efficient-metric
    """
    maes = (y_true-y_pred).abs().groupby(types).mean()
    return np.log(maes.map(lambda x: max(x, floor))).mean()
    

def train_model_regression(X, X_test, y, params, folds=None, model_type='lgb', eval_metric='mae', columns=None, plot_feature_importance=False, model=None,
                               verbose=10000, early_stopping_rounds=200, n_estimators=50000, splits=None, n_folds=3):
    """
    A function to train a variety of regression models.
    Returns dictionary with oof predictions, test predictions, scores and, if necessary, feature importances.
    
    :params: X - training data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: X_test - test data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: y - target
    :params: folds - folds to split data
    :params: model_type - type of model to use
    :params: eval_metric - metric to use
    :params: columns - columns to use. If None - use all columns
    :params: plot_feature_importance - whether to plot feature importance of LGB
    :params: model - sklearn model, works only for "sklearn" model type
    
    """
    columns = X.columns if columns is None else columns
    X_test = X_test[columns]
    splits = folds.split(X) if splits is None else splits
    n_splits = folds.n_splits if splits is None else n_folds
    
    # to set up scoring parameters
    metrics_dict = {'mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'sklearn_scoring_function': metrics.mean_absolute_error},
                    'group_mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'scoring_function': group_mean_log_mae},
                    'mse': {'lgb_metric_name': 'mse',
                        'catboost_metric_name': 'MSE',
                        'sklearn_scoring_function': metrics.mean_squared_error}
                    }

    
    result_dict = {}
    
    # out-of-fold predictions on train data
    oof = np.zeros(len(X))
    
    # averaged predictions on train data
    prediction = np.zeros(len(X_test))
    
    # list of scores on folds
    scores = []
    feature_importance = pd.DataFrame()
    
    # split and train on folds
    for fold_n, (train_index, valid_index) in enumerate(splits):
        if verbose:
            print(f'Fold {fold_n + 1} started at {time.ctime()}')
        if type(X) == np.ndarray:
            X_train, X_valid = X[columns][train_index], X[columns][valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        if model_type == 'lgb':
            model = lgb.LGBMRegressor(**params, n_estimators = n_estimators, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
                    verbose=verbose, early_stopping_rounds=early_stopping_rounds)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200, verbose_eval=verbose, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid)
            print(f'Fold {fold_n}. {eval_metric}: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'cat':
            model = CatBoostRegressor(iterations=20000,  eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
                                      loss_function=metrics_dict[eval_metric]['catboost_metric_name'])
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose_eval=verbose)

            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test)
            

        
        oof[valid_index] = y_pred_valid.reshape(-1,)
        if eval_metric != 'group_mae':
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
        else:
            scores.append(metrics_dict[eval_metric]['scoring_function'](y_valid, y_pred_valid, X_valid['type']))

        prediction += y_pred    
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_splits
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= n_splits
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12))
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)')
            
            result_dict['feature_importance'] = feature_importance
        
    return result_dict
    


def train_model_classification(X, X_test, y, params, folds, model_type='lgb', eval_metric='auc', columns=None, plot_feature_importance=False, model=None,
                               verbose=10000, early_stopping_rounds=200, n_estimators=50000, splits=None, n_folds=3, averaging='usual', n_jobs=-1):
    """
    A function to train a variety of classification models.
    Returns dictionary with oof predictions, test predictions, scores and, if necessary, feature importances.
    
    :params: X - training data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: X_test - test data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: y - target
    :params: folds - folds to split data
    :params: model_type - type of model to use
    :params: eval_metric - metric to use
    :params: columns - columns to use. If None - use all columns
    :params: plot_feature_importance - whether to plot feature importance of LGB
    :params: model - sklearn model, works only for "sklearn" model type
    
    """
    columns = X.columns if columns is None else columns
    n_splits = folds.n_splits if splits is None else n_folds
    X_test = X_test[columns]
    
    # to set up scoring parameters
    metrics_dict = {'auc': {'lgb_metric_name': eval_auc,
                        'catboost_metric_name': 'AUC',
                        'sklearn_scoring_function': metrics.roc_auc_score},
                    }
    
    result_dict = {}
    if averaging == 'usual':
        # out-of-fold predictions on train data
        oof = np.zeros((len(X), 1))

        # averaged predictions on train data
        prediction = np.zeros((len(X_test), 1))
        
    elif averaging == 'rank':
        # out-of-fold predictions on train data
        oof = np.zeros((len(X), 1))

        # averaged predictions on train data
        prediction = np.zeros((len(X_test), 1))

    
    # list of scores on folds
    scores = []
    feature_importance = pd.DataFrame()
    
    # split and train on folds
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        if type(X) == np.ndarray:
            X_train, X_valid = X[columns][train_index], X[columns][valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        if model_type == 'lgb':
            model = lgb.LGBMClassifier(**params, n_estimators=n_estimators, n_jobs = n_jobs)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
                    verbose=verbose, early_stopping_rounds=early_stopping_rounds)
            
            y_pred_valid = model.predict_proba(X_valid)[:, 1]
            y_pred = model.predict_proba(X_test, num_iteration=model.best_iteration_)[:, 1]
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=n_estimators, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=verbose, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid)
            print(f'Fold {fold_n}. {eval_metric}: {score:.4f}.')
            print('')
            
            y_pred = model.predict_proba(X_test)
        
        if model_type == 'cat':
            model = CatBoostClassifier(iterations=n_estimators, eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
                                      loss_function='Logloss') #,early_stopping_rounds=early_stopping_rounds
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose_eval=verbose)

            # y_pred_valid = model.predict(X_valid)
            # y_pred = model.predict(X_test)

            y_pred_valid = model.predict_proba(X_valid)[:, 1]
            y_pred = model.predict_proba(X_test)[:, 1] #, ntree_end=model.best_iteration_
        
        if averaging == 'usual':
            
            oof[valid_index] = y_pred_valid.reshape(-1, 1)
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
            
            prediction += y_pred.reshape(-1, 1)

        elif averaging == 'rank':
                                  
            oof[valid_index] = y_pred_valid.reshape(-1, 1)
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
                                  
            prediction += pd.Series(y_pred).rank().values.reshape(-1, 1)        
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_splits
    
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= n_splits
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            bottom_cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[-50:].index 
            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12))
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
            plt.title('LGB Features (avg over folds)')
            
            result_dict['feature_importance'] = feature_importance
            result_dict['top_columns'] = cols
            result_dict['bottom_columns'] = bottom_cols
        
    return result_dict

# %%
cat_cols = ['MON_12_CUST_CNT_PTY_ID','AI_STAR_SCO','WTHR_OPN_ONL_ICO',
'SHH_BCK','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU'] #'COR_KEY_PROD_HLD_NBR',
question_cols = ['REG_CPT','CUR_YEAR_MID_BUS_INC']
large_cale_cols = ['ICO_CUR_MON_ACM_TRX_AMT',
'COUNTER_CUR_YEAR_CNT_AMT',
'PUB_TO_PRV_TRX_AMT_CUR_YEAR',
'MON_12_EXT_SAM_TRSF_IN_AMT',
'MON_12_EXT_SAM_TRSF_OUT_AMT',
'MON_12_EXT_SAM_AMT',
'CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT',
'CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT',
'LAST_12_MON_COR_DPS_TM_PNT_BAL_PEAK_VAL',
'CUR_MON_VAL_VLD_CUST_NED_HLD_YEAR_DAY_AVG',
'LAST_12_MON_COR_DPS_DAY_AVG_BAL',
'LAST_12_MON_DIF_NM_MON_AVG_TRX_AMT_NAV',
'LAST_12_MON_MON_AVG_TRX_AMT_NAV'
]
continue_cols = []
for col in train.columns:
    if col not in ['CUST_UID','LABEL']+cat_cols+question_cols+large_cale_cols:
        continue_cols.append(col)
if 'MON_12_CUST_CNT_PTY_ID' in list(train.columns):
    need_drop_col = ['MON_12_CUST_CNT_PTY_ID']
    train = train.drop(need_drop_col, axis=1)
    test = test.drop(need_drop_col, axis=1)

for col in cat_cols:
    if col in train.columns:
        le = LabelEncoder()
        le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
        train[col] = le.transform(list(train[col].astype(str).values))
        test[col] = le.transform(list(test[col].astype(str).values))   

# single_onehot = ['MON_12_CUST_CNT_PTY_ID','AI_STAR_SCO','WTHR_OPN_ONL_ICO',
# 'SHH_BCK','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']
# for col in single_onehot:
#     try:
#         print("%s_one_hot"%col)
#         train[col + 'one_hot'] = OneHotEncoder().fit_transform(train[col].values.reshape(-1, 1))
#         test[col + 'one_hot'] = OneHotEncoder().fit_transform(train[col].values.reshape(-1, 1))
#     except:
#         print("%s is not valid!"%col)

# train.head()

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
n_fold = 5
#folds = TimeSeriesSplit(n_splits=n_fold)
folds = KFold(n_splits=5)
print(train.shape,test.shape)
# Out:
# Mem. usage decreased to 54.86 Mb (1.3% reduction)
# Mem. usage decreased to 16.45 Mb (0.8% reduction)
# (40000, 174) (12000, 173)

# %%
#continue_cols+ ['CUST_UID','LABEL']+cat_cols+question_cols+large_cale_cols
X = train.sort_values('CUST_UID').drop(['LABEL', 'CUST_UID'], axis=1)
y = train.sort_values('CUST_UID')['LABEL']
X_test = test.drop(['CUST_UID'], axis=1)

def clean_inf_nan(df):
    return df.replace([np.inf, -np.inf], np.nan)   

# Cleaning infinite values to NaN
X = clean_inf_nan(X)
X_test = clean_inf_nan(X_test )


print(len(X.columns))
print(X.shape,X_test.shape)#266维度7966
# Out:
# 172
# (40000, 172) (12000, 172)

# %%
out_path = './output/seeds/'
averag = 'rank'#'usual'
model_name = 'lgb'
seeds = [11,47,38,2011,2021,95,325,4,36,67]
for seed in seeds:
    params = {'num_leaves': 256,
            'min_child_samples': 79,
            'objective': 'binary',
            'max_depth': 13,
            'learning_rate': 0.03,
            "boosting_type": "gbdt",
            "subsample_freq": 3,
            "subsample": 0.9,
            "bagging_seed": seed,
            "metric": 'auc',
            "verbosity": -1,
            'reg_alpha': 0.3,
            'reg_lambda': 0.3,
            'colsample_bytree': 0.9#,
            #'categorical_feature': cat_cols
            }

    result_dict_lgb = train_model_classification(X=X, X_test=X_test, y=y, params=params, folds=folds, model_type='lgb', eval_metric='auc', plot_feature_importance=True,
                                                        verbose=200, early_stopping_rounds=200, n_estimators=5000, averaging=averag, n_jobs=-1)
    test["LABEL"] = result_dict_lgb['prediction']
    columns = ["CUST_UID","LABEL"]
    results = test[columns]
    print(results.head())
    scores = result_dict_lgb['scores']
    #'CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores))
    #results.to_csv(out_path+model_name+"_fload_"+str(n_fold)+"CV_mean_score{0:.4f}std: {1:.4f}.csv".format(np.mean(scores), np.std(scores)),index=None)
    results.to_csv(out_path+model_name+'_'+str(seed)+'_172fea_test_'+averag+'_score{0:.4f}.txt'.format(np.mean(scores)),sep=' ',index=0,header=0)
# Out:
# Fold 1 started at Thu May 12 15:19:18 2022
# [200]	training's auc: 0.965498	training's auc: 0.965498	valid_1's auc: 0.862878	valid_1's auc: 0.862879
# [400]	training's auc: 0.989306	training's auc: 0.989305	valid_1's auc: 0.862534	valid_1's auc: 0.862534
# Fold 2 started at Thu May 12 15:21:06 2022
# [200]	training's auc: 0.968116	training's auc: 0.968117	valid_1's auc: 0.865483	valid_1's auc: 0.865485
# [400]	training's auc: 0.990356	training's auc: 0.990355	valid_1's auc: 0.864915	valid_1's auc: 0.864913
# Fold 3 started at Thu May 12 15:22:47 2022
# [200]	training's auc: 0.967458	training's auc: 0.967457	valid_1's auc: 0.860655	valid_1's auc: 0.860655
# [400]	training's auc: 0.990503	training's auc: 0.990504	valid_1's auc: 0.859606	valid_1's auc: 0.859606
# Fold 4 started at Thu May 12 15:24:28 2022
# [200]	training's auc: 0.964736	training's auc: 0.964735	valid_1's auc: 0.867019	valid_1's auc: 0.867019
# [400]	training's auc: 0.98857	training's auc: 0.98857	valid_1's auc: 0.866809	valid_1's auc: 0.866809
# Fold 5 started at Thu May 12 15:26:35 2022
# [200]	training's auc: 0.966322	training's auc: 0.966323	valid_1's auc: 0.870276	valid_1's auc: 0.870276
# CV mean score: 0.8656, std: 0.0033.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6603.199999999999818
# 1  68883d45646d44d8b851476058e4500d  1612.799999999999955
# 2  2b93dfa58f10463a937cd42cc42e54f7  7855.800000000000182
# 3  94fc13e16dac4642ab7544d8889e8579  2391.800000000000182
# 4  6be5af4911964a31a0b5cf115799ace6  7406.800000000000182
# Fold 1 started at Thu May 12 15:27:58 2022
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-e55bf37fc74d> in <module>
#      22
#      23     result_dict_lgb = train_model_classification(X=X, X_test=X_test, y=y, params=params, folds=folds, model_type='lgb', eval_metric='auc', plot_feature_importance=True,
# ---> 24                                                         verbose=200, early_stopping_rounds=200, n_estimators=5000, averaging=averag, n_jobs=-1)
#      25     test["LABEL"] = result_dict_lgb['prediction']
#      26     columns = ["CUST_UID","LABEL"]
#
# <ipython-input-49-5e0584766d9c> in train_model_classification(X, X_test, y, params, folds, model_type, eval_metric, columns, plot_feature_importance, model, verbose, early_stopping_rounds, n_estimators, splits, n_folds, averaging, n_jobs)
#     258             model.fit(X_train, y_train,
#     259                     eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
# --> 260                     verbose=verbose, early_stopping_rounds=early_stopping_rounds)
#     261
#     262             y_pred_valid = model.predict_proba(X_valid)[:, 1]
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     970                     eval_metric=eval_metric, early_stopping_rounds=early_stopping_rounds,
#     971                     verbose=verbose, feature_name=feature_name, categorical_feature=categorical_feature,
# --> 972                     callbacks=callbacks, init_model=init_model)
#     973         return self
#     974
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     756             init_model=init_model,
#     757             feature_name=feature_name,
# --> 758             callbacks=callbacks
#     759         )
#     760
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     297             if is_valid_contain_train:
#     298                 evaluation_result_list.extend(booster.eval_train(feval))
# --> 299             evaluation_result_list.extend(booster.eval_valid(feval))
#     300         try:
#     301             for cb in callbacks_after_iter:
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\basic.py in eval_valid(self, feval)
#    3269             List with evaluation results.
#    3270         """
# -> 3271         return [item for i in range(1, self.__num_dataset)
#    3272                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    3273
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\basic.py in <listcomp>(.0)
#    3270         """
#    3271         return [item for i in range(1, self.__num_dataset)
# -> 3272                 for item in self.__inner_eval(self.name_valid_sets[i - 1], i, feval)]
#    3273
#    3274     def save_model(self, filename, num_iteration=None, start_iteration=0, importance_type='split'):
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\basic.py in __inner_eval(self, data_name, data_idx, feval)
#    3807                 if eval_function is None:
#    3808                     continue
# -> 3809                 feval_ret = eval_function(self.__inner_predict(data_idx), cur_data)
#    3810                 if isinstance(feval_ret, list):
#    3811                     for eval_name, val, is_higher_better in feval_ret:
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\lightgbm\sklearn.py in __call__(self, preds, dataset)
#     174         argc = len(signature(self.func).parameters)
#     175         if argc == 2:
# --> 176             return self.func(labels, preds)
#     177         elif argc == 3:
#     178             return self.func(labels, preds, dataset.get_weight())
#
# <ipython-input-49-5e0584766d9c> in eval_auc(y_true, y_pred)
#      47     Fast auc eval function for lgb.
#      48     """
# ---> 49     return 'auc', fast_auc(y_true, y_pred), True
#      50
#      51
#
# <ipython-input-49-5e0584766d9c> in fast_auc(y_true, y_prob)
#      37     for i in range(n):
#      38         y_i = y_true[i]
# ---> 39         nfalse += (1 - y_i)
#      40         auc += y_i * nfalse
#      41     auc /= (nfalse * (n - nfalse))
#
# KeyboardInterrupt:

# %%
#0.8657 std 0.0029.train_fea_genb6 drop80fea #0.86188
#0.8672, std: 0.0037.train_fea_genb7 drop40fea
#0.8606, std: 0.0034. train_fea_genb8 remain 180fea

#lgb_rank_res = pd.read_csv('./output/b_bang/lgb_drop_6_cols_final_rank_score0.8749.txt',sep=' ',header=None)
#xgb_rank_res = pd.read_csv('./output/xgb2_fload_5_CV_rank_score0.9509.txt',sep=' ',header=None)
# Out:
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6394.000000000000000
# 1  68883d45646d44d8b851476058e4500d  1921.799999999999955
# 2  2b93dfa58f10463a937cd42cc42e54f7  7678.399999999999636
# 3  94fc13e16dac4642ab7544d8889e8579  1889.400000000000091
# 4  6be5af4911964a31a0b5cf115799ace6  6043.399999999999636

# %%
seeds = [11,47,38,2011,2021,95,325,4,36,67]
for seed in seeds:
    averag = 'rank'
    model_name = 'xgb'
    xgb_params = {'eta': 0.03,
                'max_depth': 11,#5
                'subsample': 0.85,
                'objective': 'binary:logistic',
                'eval_metric': 'auc',
                'seed': seed,
                'silent': True,
                'nthread': -1,
                'tree_method': 'gpu_hist'}
    result_dict_xgb = train_model_classification(X=X, X_test=X_test, y=y, params=xgb_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
                                                        verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)

    test["LABEL"] = result_dict_xgb['prediction']
    columns = ["CUST_UID","LABEL"]
    results = test[columns]
    print(results.head())

    scores = result_dict_xgb['scores']
    #'CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores))
    #results.to_csv(out_path+model_name+"_fload_"+str(n_fold)+"CV_mean_score{0:.4f}.csv".format(np.mean(scores)),index=None)
    results.to_csv(out_path+model_name+'_'+str(seed)+'_remain180fea_test_corr_cols_'+averag+'_score{0:.4f}.txt'.format(np.mean(scores)),sep=' ',index=0,header=0)
# Out:
# Fold 1 started at Thu May 12 01:44:36 2022
# [01:44:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89147	valid_data-auc:0.81145
# [500]	train-auc:0.99983	valid_data-auc:0.86194
# [549]	train-auc:0.99989	valid_data-auc:0.86190
# Fold 2 started at Thu May 12 01:45:45 2022
# [01:45:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89125	valid_data-auc:0.81648
# [500]	train-auc:0.99980	valid_data-auc:0.86423
# [602]	train-auc:0.99988	valid_data-auc:0.86390
# Fold 3 started at Thu May 12 01:46:57 2022
# [01:46:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89243	valid_data-auc:0.80505
# [500]	train-auc:0.99982	valid_data-auc:0.85924
# [538]	train-auc:0.99986	valid_data-auc:0.85923
# Fold 4 started at Thu May 12 01:48:10 2022
# [01:48:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88816	valid_data-auc:0.81344
# [479]	train-auc:0.99978	valid_data-auc:0.86619
# Fold 5 started at Thu May 12 01:49:09 2022
# [01:49:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89393	valid_data-auc:0.82023
# [500]	train-auc:0.99980	valid_data-auc:0.86940
# [516]	train-auc:0.99981	valid_data-auc:0.86956
# CV mean score: 0.8648, std: 0.0034.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6694.199999999999818
# 1  68883d45646d44d8b851476058e4500d  1776.400000000000091
# 2  2b93dfa58f10463a937cd42cc42e54f7  6911.800000000000182
# 3  94fc13e16dac4642ab7544d8889e8579  2192.599999999999909
# 4  6be5af4911964a31a0b5cf115799ace6  7188.600000000000364
# Fold 1 started at Thu May 12 01:50:13 2022
# [01:50:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89146	valid_data-auc:0.81044
# [500]	train-auc:0.99982	valid_data-auc:0.86272
# [652]	train-auc:0.99994	valid_data-auc:0.86219
# Fold 2 started at Thu May 12 01:51:28 2022
# [01:51:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89349	valid_data-auc:0.81512
# [500]	train-auc:0.99979	valid_data-auc:0.86554
# [656]	train-auc:0.99990	valid_data-auc:0.86500
# Fold 3 started at Thu May 12 01:52:49 2022
# [01:52:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89035	valid_data-auc:0.81130
# [500]	train-auc:0.99982	valid_data-auc:0.86031
# [541]	train-auc:0.99986	valid_data-auc:0.86016
# Fold 4 started at Thu May 12 01:53:54 2022
# [01:53:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89149	valid_data-auc:0.81651
# [423]	train-auc:0.99951	valid_data-auc:0.86696
# Fold 5 started at Thu May 12 01:54:50 2022
# [01:54:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89126	valid_data-auc:0.81480
# [500]	train-auc:0.99979	valid_data-auc:0.86934
# [553]	train-auc:0.99986	valid_data-auc:0.86919
# CV mean score: 0.8654, std: 0.0032.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6932.399999999999636
# 1  68883d45646d44d8b851476058e4500d  1702.400000000000091
# 2  2b93dfa58f10463a937cd42cc42e54f7  7353.000000000000000
# 3  94fc13e16dac4642ab7544d8889e8579  2224.000000000000000
# 4  6be5af4911964a31a0b5cf115799ace6  7304.199999999999818
# Fold 1 started at Thu May 12 01:55:59 2022
# [01:55:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88830	valid_data-auc:0.81278
# [500]	train-auc:0.99984	valid_data-auc:0.86193
# [501]	train-auc:0.99984	valid_data-auc:0.86190
# Fold 2 started at Thu May 12 01:57:00 2022
# [01:57:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89208	valid_data-auc:0.81709
# [433]	train-auc:0.99967	valid_data-auc:0.86494
# Fold 3 started at Thu May 12 01:57:55 2022
# [01:57:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89265	valid_data-auc:0.81279
# [500]	train-auc:0.99983	valid_data-auc:0.85981
# [674]	train-auc:0.99994	valid_data-auc:0.85951
# Fold 4 started at Thu May 12 01:59:20 2022
# [01:59:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89289	valid_data-auc:0.81163
# [500]	train-auc:0.99977	valid_data-auc:0.86596
# [591]	train-auc:0.99989	valid_data-auc:0.86557
# Fold 5 started at Thu May 12 02:00:27 2022
# [02:00:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89120	valid_data-auc:0.82468
# [500]	train-auc:0.99980	valid_data-auc:0.86988
# [510]	train-auc:0.99981	valid_data-auc:0.86984
# CV mean score: 0.8649, std: 0.0036.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  7187.000000000000000
# 1  68883d45646d44d8b851476058e4500d  1702.400000000000091
# 2  2b93dfa58f10463a937cd42cc42e54f7  7236.800000000000182
# 3  94fc13e16dac4642ab7544d8889e8579  2400.000000000000000
# 4  6be5af4911964a31a0b5cf115799ace6  7401.000000000000000
# Fold 1 started at Thu May 12 02:01:34 2022
# [02:01:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89177	valid_data-auc:0.81305
# [500]	train-auc:0.99983	valid_data-auc:0.86327
# [504]	train-auc:0.99984	valid_data-auc:0.86329
# Fold 2 started at Thu May 12 02:02:36 2022
# [02:02:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89165	valid_data-auc:0.82077
# [500]	train-auc:0.99979	valid_data-auc:0.86411
# [617]	train-auc:0.99988	valid_data-auc:0.86392
# Fold 3 started at Thu May 12 02:03:51 2022
# [02:03:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89231	valid_data-auc:0.80683
# [500]	train-auc:0.99982	valid_data-auc:0.85974
# [548]	train-auc:0.99987	valid_data-auc:0.85955
# Fold 4 started at Thu May 12 02:05:00 2022
# [02:05:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89199	valid_data-auc:0.82184
# [500]	train-auc:0.99981	valid_data-auc:0.86755
# [506]	train-auc:0.99982	valid_data-auc:0.86753
# Fold 5 started at Thu May 12 02:06:06 2022
# [02:06:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88865	valid_data-auc:0.81868
# [500]	train-auc:0.99976	valid_data-auc:0.86976
# [613]	train-auc:0.99988	valid_data-auc:0.86951
# CV mean score: 0.8654, std: 0.0034.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6764.399999999999636
# 1  68883d45646d44d8b851476058e4500d  1736.599999999999909
# 2  2b93dfa58f10463a937cd42cc42e54f7  7199.000000000000000
# 3  94fc13e16dac4642ab7544d8889e8579  2416.599999999999909
# 4  6be5af4911964a31a0b5cf115799ace6  6882.000000000000000
# Fold 1 started at Thu May 12 02:07:18 2022
# [02:07:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88933	valid_data-auc:0.81601
# [500]	train-auc:0.99984	valid_data-auc:0.86256
# [576]	train-auc:0.99991	valid_data-auc:0.86249
# Fold 2 started at Thu May 12 02:08:27 2022
# [02:08:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89116	valid_data-auc:0.81909
# [500]	train-auc:0.99980	valid_data-auc:0.86425
# [514]	train-auc:0.99981	valid_data-auc:0.86419
# Fold 3 started at Thu May 12 02:09:32 2022
# [02:09:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89344	valid_data-auc:0.81543
# [500]	train-auc:0.99982	valid_data-auc:0.85911
# [588]	train-auc:0.99990	valid_data-auc:0.85896
# Fold 4 started at Thu May 12 02:10:43 2022
# [02:10:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.89114	valid_data-auc:0.82072
# [455]	train-auc:0.99969	valid_data-auc:0.86716
# Fold 5 started at Thu May 12 02:11:43 2022
# [02:11:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88721	valid_data-auc:0.81894

# %%
seeds = [11,47,38,2011,2021,95,325,4,36,67]
for seed in seeds:
    averag = 'rank'
    model_name = 'cat'
    cat_params ={
        'learning_rate':0.05,
        "od_type":"Iter",
        'od_wait':100,
        'l2_leaf_reg': 5,
        "random_seed": seed,
        "depth": 10,
        'use_best_model': True,
        'verbose': 100
        
    }                      
    result_dict_cat = train_model_classification(X=X, X_test=X_test, y=y, params=cat_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
                                                        verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)
    test["LABEL"] = result_dict_cat['prediction']
    columns = ["CUST_UID","LABEL"]
    results = test[columns]
    print(results.head())

    scores = result_dict_cat['scores']
    #'CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores))
    #results.to_csv(out_path+model_name+"_fload_"+str(n_fold)+"CV_mean_score{0:.4f}.csv".format(np.mean(scores)),index=None)
    results.to_csv(out_path+model_name+'_'+str(seed)+'_remain174fea_test_corr_cols_'+averag+'_score{0:.4f}.txt'.format(np.mean(scores)),sep=' ',index=0,header=0)
# Out:
# Fold 1 started at Thu May 12 15:28:36 2022
# 0:	test: 0.7856905	best: 0.7856905 (0)	total: 647ms	remaining: 53m 53s
# 500:	test: 0.8626333	best: 0.8628462 (471)	total: 3m 57s	remaining: 35m 33s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8628462154
# bestIteration = 471
#
# Shrink model to first 472 iterations.
# Fold 2 started at Thu May 12 15:33:08 2022
# 0:	test: 0.7787549	best: 0.7787549 (0)	total: 468ms	remaining: 38m 58s
# 500:	test: 0.8653638	best: 0.8654865 (495)	total: 3m 48s	remaining: 34m 14s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8654864816
# bestIteration = 495
#
# Shrink model to first 496 iterations.
# Fold 3 started at Thu May 12 15:37:40 2022
# 0:	test: 0.7842452	best: 0.7842452 (0)	total: 444ms	remaining: 36m 59s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8615015967
# bestIteration = 343
#
# Shrink model to first 344 iterations.
# Fold 4 started at Thu May 12 15:41:04 2022
# 0:	test: 0.7875074	best: 0.7875074 (0)	total: 484ms	remaining: 40m 17s
# 500:	test: 0.8646444	best: 0.8655359 (406)	total: 3m 49s	remaining: 34m 20s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8655358633
# bestIteration = 406
#
# Shrink model to first 407 iterations.
# Fold 5 started at Thu May 12 15:44:56 2022
# 0:	test: 0.7959891	best: 0.7959891 (0)	total: 465ms	remaining: 38m 43s
# 500:	test: 0.8710229	best: 0.8711768 (483)	total: 3m 48s	remaining: 34m 9s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8711768435
# bestIteration = 483
#
# Shrink model to first 484 iterations.
# CV mean score: 0.8653, std: 0.0033.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6621.000000000000000
# 1  68883d45646d44d8b851476058e4500d  1486.000000000000000
# 2  2b93dfa58f10463a937cd42cc42e54f7  7278.199999999999818
# 3  94fc13e16dac4642ab7544d8889e8579  3172.400000000000091
# 4  6be5af4911964a31a0b5cf115799ace6  7137.000000000000000
# Fold 1 started at Thu May 12 15:49:23 2022
# 0:	test: 0.7904975	best: 0.7904975 (0)	total: 480ms	remaining: 39m 59s
# 500:	test: 0.8614500	best: 0.8616123 (483)	total: 3m 46s	remaining: 33m 57s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8619546412
# bestIteration = 595
#
# Shrink model to first 596 iterations.
# Fold 2 started at Thu May 12 15:54:38 2022
# 0:	test: 0.7695876	best: 0.7695876 (0)	total: 444ms	remaining: 37m
# 500:	test: 0.8685327	best: 0.8687286 (485)	total: 3m 44s	remaining: 33m 40s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8687286352
# bestIteration = 485
#
# Shrink model to first 486 iterations.
# Fold 3 started at Thu May 12 15:59:01 2022
# 0:	test: 0.7849404	best: 0.7849404 (0)	total: 464ms	remaining: 38m 38s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8615448342
# bestIteration = 343
#
# Shrink model to first 344 iterations.
# Fold 4 started at Thu May 12 16:02:22 2022
# 0:	test: 0.7850651	best: 0.7850651 (0)	total: 463ms	remaining: 38m 35s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8676917923
# bestIteration = 393
#
# Shrink model to first 394 iterations.
# Fold 5 started at Thu May 12 16:06:06 2022
# 0:	test: 0.7948569	best: 0.7948569 (0)	total: 467ms	remaining: 38m 52s
# 500:	test: 0.8703596	best: 0.8706583 (449)	total: 3m 46s	remaining: 33m 53s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8706583455
# bestIteration = 449
#
# Shrink model to first 450 iterations.
# CV mean score: 0.8661, std: 0.0037.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6893.399999999999636
# 1  68883d45646d44d8b851476058e4500d  1925.000000000000000
# 2  2b93dfa58f10463a937cd42cc42e54f7  7127.600000000000364
# 3  94fc13e16dac4642ab7544d8889e8579  3227.599999999999909
# 4  6be5af4911964a31a0b5cf115799ace6  7537.800000000000182
# Fold 1 started at Thu May 12 16:10:15 2022
# 0:	test: 0.7867278	best: 0.7867278 (0)	total: 450ms	remaining: 37m 31s
# 500:	test: 0.8634084	best: 0.8637477 (470)	total: 3m 46s	remaining: 33m 54s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8637476959
# bestIteration = 470
#
# Shrink model to first 471 iterations.
# Fold 2 started at Thu May 12 16:14:33 2022
# 0:	test: 0.7795198	best: 0.7795198 (0)	total: 456ms	remaining: 38m 1s
# 500:	test: 0.8658094	best: 0.8659941 (493)	total: 3m 45s	remaining: 33m 45s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8661251014
# bestIteration = 515
#
# Shrink model to first 516 iterations.
# Fold 3 started at Thu May 12 16:19:10 2022
# 0:	test: 0.7823273	best: 0.7823273 (0)	total: 456ms	remaining: 38m 1s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8607338004
# bestIteration = 388
#
# Shrink model to first 389 iterations.
# Fold 4 started at Thu May 12 16:22:50 2022
# 0:	test: 0.7827306	best: 0.7827306 (0)	total: 448ms	remaining: 37m 20s
# 500:	test: 0.8648038	best: 0.8650418 (472)	total: 3m 45s	remaining: 33m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8650417737
# bestIteration = 472
#
# Shrink model to first 473 iterations.
# Fold 5 started at Thu May 12 16:27:08 2022
# 0:	test: 0.7803818	best: 0.7803818 (0)	total: 464ms	remaining: 38m 41s
# 500:	test: 0.8700250	best: 0.8701052 (449)	total: 3m 46s	remaining: 33m 51s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8701386718
# bestIteration = 503
#
# Shrink model to first 504 iterations.
# CV mean score: 0.8652, std: 0.0031.
#                            CUST_UID                 LABEL
# 0  f5dcfe9b9e8d496d893cfcba8fcac1d4  6289.199999999999818
# 1  68883d45646d44d8b851476058e4500d  1745.000000000000000
# 2  2b93dfa58f10463a937cd42cc42e54f7  6863.000000000000000
# 3  94fc13e16dac4642ab7544d8889e8579  2876.199999999999818
# 4  6be5af4911964a31a0b5cf115799ace6  6769.199999999999818
# Fold 1 started at Thu May 12 16:31:41 2022
# 0:	test: 0.8006845	best: 0.8006845 (0)	total: 468ms	remaining: 38m 59s
# 500:	test: 0.8642810	best: 0.8644095 (459)	total: 3m 45s	remaining: 33m 46s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-ae059730e8aa> in <module>
#      15     }
#      16     result_dict_cat = train_model_classification(X=X, X_test=X_test, y=y, params=cat_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
# ---> 17                                                         verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)
#      18     test["LABEL"] = result_dict_cat['prediction']
#      19     columns = ["CUST_UID","LABEL"]
#
# <ipython-input-49-5e0584766d9c> in train_model_classification(X, X_test, y, params, folds, model_type, eval_metric, columns, plot_feature_importance, model, verbose, early_stopping_rounds, n_estimators, splits, n_folds, averaging, n_jobs)
#     286             model = CatBoostClassifier(iterations=n_estimators, eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
#     287                                       loss_function='Logloss') #,early_stopping_rounds=early_stopping_rounds
# --> 288             model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose_eval=verbose)
#     289
#     290             # y_pred_valid = model.predict(X_valid)
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\catboost\core.py in fit(self, X, y, cat_features, text_features, embedding_features, sample_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4921         self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#    4922                   eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period,
# -> 4923                   silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    4924         return self
#    4925
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\catboost\core.py in _fit(self, X, y, cat_features, text_features, embedding_features, pairs, sample_weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, use_best_model, eval_set, verbose, logging_level, plot, column_description, verbose_eval, metric_period, silent, early_stopping_rounds, save_snapshot, snapshot_file, snapshot_interval, init_model, callbacks, log_cout, log_cerr)
#    2195                 params,
#    2196                 allow_clear_pool,
# -> 2197                 train_params["init_model"]
#    2198             )
#    2199
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\catboost\core.py in _train(self, train_pool, test_pool, params, allow_clear_pool, init_model)
#    1617
#    1618     def _train(self, train_pool, test_pool, params, allow_clear_pool, init_model):
# -> 1619         self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#    1620         self._set_trained_model_attributes()
#    1621
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# _catboost.pyx in _catboost._CatBoost._train()
#
# KeyboardInterrupt:
