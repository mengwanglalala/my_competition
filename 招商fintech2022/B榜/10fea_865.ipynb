# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error, log_loss
pd.options.display.precision = 15
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor, CatBoostClassifier
import time
import datetime
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn import linear_model
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import json
# %matplotlib inline

# %env JOBLIB_TEMP_FOLDER=/tmp
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
out_path = './output/'
train_path = './data/original_train.csv'
test_path = './data/original_test_B.csv'
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
print(train.shape,test.shape)
# Out:
# (40000, 51) (12000, 50)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage(deep=True).sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                c_prec = df[col].apply(lambda x: np.finfo(x).precision).max()
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max and c_prec == np.finfo(np.float32).precision:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage(deep=True).sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df
    
def fast_auc(y_true, y_prob):
    """
    fast roc_auc computation: https://www.kaggle.com/c/microsoft-malware-prediction/discussion/76013
    """
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    nfalse = 0
    auc = 0
    n = len(y_true)
    for i in range(n):
        y_i = y_true[i]
        nfalse += (1 - y_i)
        auc += y_i * nfalse
    auc /= (nfalse * (n - nfalse))
    return auc


def eval_auc(y_true, y_pred):
    """
    Fast auc eval function for lgb.
    """
    return 'auc', fast_auc(y_true, y_pred), True


def group_mean_log_mae(y_true, y_pred, types, floor=1e-9):
    """
    Fast metric computation for this competition: https://www.kaggle.com/c/champs-scalar-coupling
    Code is from this kernel: https://www.kaggle.com/uberkinder/efficient-metric
    """
    maes = (y_true-y_pred).abs().groupby(types).mean()
    return np.log(maes.map(lambda x: max(x, floor))).mean()
    

def train_model_regression(X, X_test, y, params, folds=None, model_type='lgb', eval_metric='mae', columns=None, plot_feature_importance=False, model=None,
                               verbose=10000, early_stopping_rounds=200, n_estimators=50000, splits=None, n_folds=3):
    """
    A function to train a variety of regression models.
    Returns dictionary with oof predictions, test predictions, scores and, if necessary, feature importances.
    
    :params: X - training data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: X_test - test data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: y - target
    :params: folds - folds to split data
    :params: model_type - type of model to use
    :params: eval_metric - metric to use
    :params: columns - columns to use. If None - use all columns
    :params: plot_feature_importance - whether to plot feature importance of LGB
    :params: model - sklearn model, works only for "sklearn" model type
    
    """
    columns = X.columns if columns is None else columns
    X_test = X_test[columns]
    splits = folds.split(X) if splits is None else splits
    n_splits = folds.n_splits if splits is None else n_folds
    
    # to set up scoring parameters
    metrics_dict = {'mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'sklearn_scoring_function': metrics.mean_absolute_error},
                    'group_mae': {'lgb_metric_name': 'mae',
                        'catboost_metric_name': 'MAE',
                        'scoring_function': group_mean_log_mae},
                    'mse': {'lgb_metric_name': 'mse',
                        'catboost_metric_name': 'MSE',
                        'sklearn_scoring_function': metrics.mean_squared_error}
                    }

    
    result_dict = {}
    
    # out-of-fold predictions on train data
    oof = np.zeros(len(X))
    
    # averaged predictions on train data
    prediction = np.zeros(len(X_test))
    
    # list of scores on folds
    scores = []
    feature_importance = pd.DataFrame()
    
    # split and train on folds
    for fold_n, (train_index, valid_index) in enumerate(splits):
        if verbose:
            print(f'Fold {fold_n + 1} started at {time.ctime()}')
        if type(X) == np.ndarray:
            X_train, X_valid = X[columns][train_index], X[columns][valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        if model_type == 'lgb':
            model = lgb.LGBMRegressor(**params, n_estimators = n_estimators, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
                    verbose=verbose, early_stopping_rounds=early_stopping_rounds)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200, verbose_eval=verbose, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid)
            print(f'Fold {fold_n}. {eval_metric}: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'cat':
            model = CatBoostRegressor(iterations=20000,  eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
                                      loss_function=metrics_dict[eval_metric]['catboost_metric_name'])
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose_eval=verbose)

            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test)
            

        
        oof[valid_index] = y_pred_valid.reshape(-1,)
        if eval_metric != 'group_mae':
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
        else:
            scores.append(metrics_dict[eval_metric]['scoring_function'](y_valid, y_pred_valid, X_valid['type']))

        prediction += y_pred    
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_splits
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= n_splits
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12))
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)')
            
            result_dict['feature_importance'] = feature_importance
        
    return result_dict
    


def train_model_classification(X, X_test, y, params, folds, model_type='lgb', eval_metric='auc', columns=None, plot_feature_importance=False, model=None,
                               verbose=10000, early_stopping_rounds=200, n_estimators=50000, splits=None, n_folds=3, averaging='usual', n_jobs=-1):
    """
    A function to train a variety of classification models.
    Returns dictionary with oof predictions, test predictions, scores and, if necessary, feature importances.
    
    :params: X - training data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: X_test - test data, can be pd.DataFrame or np.ndarray (after normalizing)
    :params: y - target
    :params: folds - folds to split data
    :params: model_type - type of model to use
    :params: eval_metric - metric to use
    :params: columns - columns to use. If None - use all columns
    :params: plot_feature_importance - whether to plot feature importance of LGB
    :params: model - sklearn model, works only for "sklearn" model type
    
    """
    columns = X.columns if columns is None else columns
    n_splits = folds.n_splits if splits is None else n_folds
    X_test = X_test[columns]
    
    # to set up scoring parameters
    metrics_dict = {'auc': {'lgb_metric_name': eval_auc,
                        'catboost_metric_name': 'AUC',
                        'sklearn_scoring_function': metrics.roc_auc_score},
                    }
    
    result_dict = {}
    if averaging == 'usual':
        # out-of-fold predictions on train data
        oof = np.zeros((len(X), 1))

        # averaged predictions on train data
        prediction = np.zeros((len(X_test), 1))
        
    elif averaging == 'rank':
        # out-of-fold predictions on train data
        oof = np.zeros((len(X), 1))

        # averaged predictions on train data
        prediction = np.zeros((len(X_test), 1))

    
    # list of scores on folds
    scores = []
    feature_importance = pd.DataFrame()
    
    # split and train on folds
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
        print(f'Fold {fold_n + 1} started at {time.ctime()}')
        if type(X) == np.ndarray:
            X_train, X_valid = X[columns][train_index], X[columns][valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        if model_type == 'lgb':
            model = lgb.LGBMClassifier(**params, n_estimators=n_estimators, n_jobs = n_jobs)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric=metrics_dict[eval_metric]['lgb_metric_name'],
                    verbose=verbose, early_stopping_rounds=early_stopping_rounds)
            
            y_pred_valid = model.predict_proba(X_valid)[:, 1]
            y_pred = model.predict_proba(X_test, num_iteration=model.best_iteration_)[:, 1]
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=n_estimators, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=verbose, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid)
            print(f'Fold {fold_n}. {eval_metric}: {score:.4f}.')
            print('')
            
            y_pred = model.predict_proba(X_test)
        
        if model_type == 'cat':
            model = CatBoostClassifier(iterations=n_estimators, eval_metric=metrics_dict[eval_metric]['catboost_metric_name'], **params,
                                      loss_function='Logloss') #,early_stopping_rounds=early_stopping_rounds
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose_eval=verbose)

            # y_pred_valid = model.predict(X_valid)
            # y_pred = model.predict(X_test)

            y_pred_valid = model.predict_proba(X_valid)[:, 1]
            y_pred = model.predict_proba(X_test)[:, 1] #, ntree_end=model.best_iteration_
        
        if averaging == 'usual':
            
            oof[valid_index] = y_pred_valid.reshape(-1, 1)
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
            
            prediction += y_pred.reshape(-1, 1)

        elif averaging == 'rank':
                                  
            oof[valid_index] = y_pred_valid.reshape(-1, 1)
            scores.append(metrics_dict[eval_metric]['sklearn_scoring_function'](y_valid, y_pred_valid))
                                  
            prediction += pd.Series(y_pred).rank().values.reshape(-1, 1)        
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_splits
    
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    result_dict['oof'] = oof
    result_dict['prediction'] = prediction
    result_dict['scores'] = scores
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= n_splits
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            bottom_cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[-50:].index 
            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12))
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
            plt.title('LGB Features (avg over folds)')
            
            result_dict['feature_importance'] = feature_importance
            result_dict['top_columns'] = cols
            result_dict['bottom_columns'] = bottom_cols
        
    return result_dict

# %%
cat_cols = ['MON_12_CUST_CNT_PTY_ID','AI_STAR_SCO','WTHR_OPN_ONL_ICO',
'SHH_BCK','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU'] #'COR_KEY_PROD_HLD_NBR',
question_cols = ['REG_CPT','CUR_YEAR_MID_BUS_INC']
large_cale_cols = ['ICO_CUR_MON_ACM_TRX_AMT',
'COUNTER_CUR_YEAR_CNT_AMT',
'PUB_TO_PRV_TRX_AMT_CUR_YEAR',
'MON_12_EXT_SAM_TRSF_IN_AMT',
'MON_12_EXT_SAM_TRSF_OUT_AMT',
'MON_12_EXT_SAM_AMT',
'CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT',
'CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT',
'LAST_12_MON_COR_DPS_TM_PNT_BAL_PEAK_VAL',
'CUR_MON_VAL_VLD_CUST_NED_HLD_YEAR_DAY_AVG',
'LAST_12_MON_COR_DPS_DAY_AVG_BAL',
'LAST_12_MON_DIF_NM_MON_AVG_TRX_AMT_NAV',
'LAST_12_MON_MON_AVG_TRX_AMT_NAV'
]
continue_cols = []
for col in train.columns:
    if col not in ['CUST_UID','LABEL']+cat_cols+question_cols+large_cale_cols:
        continue_cols.append(col)

need_drop_col = ['MON_12_CUST_CNT_PTY_ID']
train = train.drop(need_drop_col, axis=1)
test = test.drop(need_drop_col, axis=1)

for col in cat_cols:
    if col in train.columns:
        le = LabelEncoder()
        le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
        train[col] = le.transform(list(train[col].astype(str).values))
        test[col] = le.transform(list(test[col].astype(str).values))   

# single_onehot = ['MON_12_CUST_CNT_PTY_ID','AI_STAR_SCO','WTHR_OPN_ONL_ICO',
# 'SHH_BCK','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']
# for col in single_onehot:
#     try:
#         print("%s_one_hot"%col)
#         train[col + 'one_hot'] = OneHotEncoder().fit_transform(train[col].values.reshape(-1, 1))
#         test[col + 'one_hot'] = OneHotEncoder().fit_transform(train[col].values.reshape(-1, 1))
#     except:
#         print("%s is not valid!"%col)

# train.head()
need_drop_col = ['CUR_YEAR_MON_AGV_TRX_CNT','CUR_YEAR_COR_DMND_DPS_DAY_AVG_BAL','CUR_YEAR_COR_DPS_YEAR_DAY_AVG_INCR','CUR_YEAR_MID_BUS_INC','AI_STAR_SCO',
'CUR_MON_COR_DPS_MON_DAY_AVG_BAL','ICO_CUR_MON_ACM_TRX_AMT','MON_12_AGV_TRX_CNT','MON_12_ACM_LVE_ACT_CNT','MON_12_AGV_LVE_ACT_CNT']
fea_box = []
for col in list(train.columns)[2:]:
    if col in need_drop_col + cat_cols: continue
    fea_box.append(col)

print(len(fea_box),fea_box)
# Out:
# 34 ['AGN_CNT_RCT_12_MON', 'ICO_CUR_MON_ACM_TRX_TM', 'NB_RCT_3_MON_LGN_TMS_AGV', 'AGN_CUR_YEAR_AMT', 'AGN_CUR_YEAR_WAG_AMT', 'AGN_AGR_LATEST_AGN_AMT', 'COUNTER_CUR_YEAR_CNT_AMT', 'PUB_TO_PRV_TRX_AMT_CUR_YEAR', 'MON_12_EXT_SAM_TRSF_IN_AMT', 'MON_12_EXT_SAM_TRSF_OUT_AMT', 'MON_12_EXT_SAM_NM_TRSF_OUT_CNT', 'MON_12_EXT_SAM_AMT', 'CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT', 'CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT', 'MON_12_TRX_AMT_MAX_AMT_PCTT', 'MON_12_ACM_ENTR_ACT_CNT', 'MON_12_AGV_ENTR_ACT_CNT', 'CUR_YEAR_PUB_TO_PRV_TRX_PTY_CNT', 'MON_6_50_UP_ENTR_ACT_CNT', 'MON_6_50_UP_LVE_ACT_CNT', 'CUR_YEAR_COUNTER_ENCASH_CNT', 'MON_12_ACT_OUT_50_UP_CNT_PTY_QTY', 'MON_12_ACT_IN_50_UP_CNT_PTY_QTY', 'LAST_12_MON_COR_DPS_TM_PNT_BAL_PEAK_VAL', 'LAST_12_MON_COR_DPS_DAY_AVG_BAL', 'LAST_12_MON_DIF_NM_MON_AVG_TRX_AMT_NAV', 'LAST_12_MON_MON_AVG_TRX_AMT_NAV', 'COR_KEY_PROD_HLD_NBR', 'EMP_NBR', 'REG_CPT', 'HLD_DMS_CCY_ACT_NBR', 'REG_DT', 'OPN_TM', 'HLD_FGN_CCY_ACT_NBR']

# %%
train = reduce_mem_usage(train[['CUST_UID','LABEL'] + fea_box])
test = reduce_mem_usage(test[['CUST_UID'] + fea_box])
# Out:
# Mem. usage decreased to 13.81 Mb (1.9% reduction)
# Mem. usage decreased to  4.13 Mb (0.0% reduction)

# %%
#continue_cols+ ['CUST_UID','LABEL']+cat_cols+question_cols+large_cale_cols
from random import sample
import copy
original_train = copy.deepcopy(train)
original_test = copy.deepcopy(test)


#print(sorted(result))

# %%
seeds = [11]
f = "./output/15fea_res/test.txt"
a = 300
history  = []
with open(f,"w") as file:   #”w"代表着每次运行都覆盖内容
    for i in range(a):
        result = sample(fea_box,15)
        if sorted(result) in history: continue
        history.append(sorted(result))
        
        train = reduce_mem_usage(original_train[['CUST_UID','LABEL'] + result])
        test = reduce_mem_usage(original_test[['CUST_UID'] + result])
        n_fold = 5
        #folds = TimeSeriesSplit(n_splits=n_fold)
        folds = KFold(n_splits=5)
        X = train.sort_values('CUST_UID').drop(['LABEL', 'CUST_UID'], axis=1)
        y = train.sort_values('CUST_UID')['LABEL']
        X_test = test.drop(['CUST_UID'], axis=1)

        def clean_inf_nan(df):
            return df.replace([np.inf, -np.inf], np.nan)   

        # Cleaning infinite values to NaN
        X = clean_inf_nan(X)
        X_test = clean_inf_nan(X_test )


        print(len(X.columns))
        print(X.shape,X_test.shape)#266维度7966

        averag = 'rank'
        model_name = 'xgb'
        xgb_params = {'eta': 0.03,
                    'max_depth': 11,#5
                    'subsample': 0.85,
                    'objective': 'binary:logistic',
                    'eval_metric': 'auc',
                    'seed': 11,
                    'silent': True,
                    'nthread': -1,
                    'tree_method': 'gpu_hist'}
        result_dict_xgb = train_model_classification(X=X, X_test=X_test, y=y, params=xgb_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
                                                            verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)

        file.write(str(sorted(result)) + str(np.mean(result_dict_xgb['scores']))  + " "+"\n")
# Out:
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:33:52 2022
# [23:33:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.75075	valid_data-auc:0.64373
# [376]	train-auc:0.98955	valid_data-auc:0.68265
# Fold 2 started at Wed May 11 23:34:06 2022
# [23:34:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.75128	valid_data-auc:0.64638
# [435]	train-auc:0.99384	valid_data-auc:0.69911
# Fold 3 started at Wed May 11 23:34:21 2022
# [23:34:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.75554	valid_data-auc:0.64537
# [433]	train-auc:0.99354	valid_data-auc:0.68666
# Fold 4 started at Wed May 11 23:34:36 2022
# [23:34:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.75289	valid_data-auc:0.65236
# [357]	train-auc:0.98821	valid_data-auc:0.69384
# Fold 5 started at Wed May 11 23:34:51 2022
# [23:34:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.75011	valid_data-auc:0.65312
# [356]	train-auc:0.98837	valid_data-auc:0.69836
# CV mean score: 0.6967, std: 0.0065.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:35:06 2022
# [23:35:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88279	valid_data-auc:0.83378
# [427]	train-auc:0.99819	valid_data-auc:0.85783
# Fold 2 started at Wed May 11 23:35:21 2022
# [23:35:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88518	valid_data-auc:0.83496
# [472]	train-auc:0.99859	valid_data-auc:0.86010
# Fold 3 started at Wed May 11 23:35:37 2022
# [23:35:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88364	valid_data-auc:0.82778
# [350]	train-auc:0.99582	valid_data-auc:0.85235
# Fold 4 started at Wed May 11 23:35:50 2022
# [23:35:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88330	valid_data-auc:0.83271
# [360]	train-auc:0.99544	valid_data-auc:0.85870
# Fold 5 started at Wed May 11 23:36:03 2022
# [23:36:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88661	valid_data-auc:0.83255
# [392]	train-auc:0.99700	valid_data-auc:0.86139
# CV mean score: 0.8591, std: 0.0030.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:36:19 2022
# [23:36:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88590	valid_data-auc:0.82772
# [410]	train-auc:0.99765	valid_data-auc:0.85399
# Fold 2 started at Wed May 11 23:36:35 2022
# [23:36:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88670	valid_data-auc:0.83146
# [422]	train-auc:0.99771	valid_data-auc:0.86081
# Fold 3 started at Wed May 11 23:36:50 2022
# [23:36:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88519	valid_data-auc:0.82574
# [328]	train-auc:0.99372	valid_data-auc:0.85106
# Fold 4 started at Wed May 11 23:37:02 2022
# [23:37:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88193	valid_data-auc:0.82956
# [416]	train-auc:0.99729	valid_data-auc:0.85656
# Fold 5 started at Wed May 11 23:37:17 2022
# [23:37:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88343	valid_data-auc:0.83788
# [404]	train-auc:0.99691	valid_data-auc:0.86017
# CV mean score: 0.8581, std: 0.0033.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:37:33 2022
# [23:37:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88215	valid_data-auc:0.82938
# [411]	train-auc:0.99554	valid_data-auc:0.85305
# Fold 2 started at Wed May 11 23:37:47 2022
# [23:37:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88092	valid_data-auc:0.83769
# [386]	train-auc:0.99394	valid_data-auc:0.85739
# Fold 3 started at Wed May 11 23:38:02 2022
# [23:38:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88062	valid_data-auc:0.83094
# [365]	train-auc:0.99396	valid_data-auc:0.85086
# Fold 4 started at Wed May 11 23:38:15 2022
# [23:38:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87773	valid_data-auc:0.83380
# [346]	train-auc:0.99096	valid_data-auc:0.85542
# Fold 5 started at Wed May 11 23:38:27 2022
# [23:38:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88207	valid_data-auc:0.83657
# [348]	train-auc:0.99140	valid_data-auc:0.85824
# CV mean score: 0.8564, std: 0.0027.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:38:42 2022
# [23:38:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81789	valid_data-auc:0.71889
# [368]	train-auc:0.99149	valid_data-auc:0.76732
# Fold 2 started at Wed May 11 23:38:56 2022
# [23:38:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81102	valid_data-auc:0.72263
# [414]	train-auc:0.99293	valid_data-auc:0.77567
# Fold 3 started at Wed May 11 23:39:11 2022
# [23:39:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81503	valid_data-auc:0.71492
# [350]	train-auc:0.99006	valid_data-auc:0.76549
# Fold 4 started at Wed May 11 23:39:27 2022
# [23:39:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81862	valid_data-auc:0.72468
# [363]	train-auc:0.99038	valid_data-auc:0.76864
# Fold 5 started at Wed May 11 23:39:41 2022
# [23:39:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81716	valid_data-auc:0.73161
# [374]	train-auc:0.98982	valid_data-auc:0.77688
# CV mean score: 0.7731, std: 0.0043.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:39:56 2022
# [23:39:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77446	valid_data-auc:0.66995
# [379]	train-auc:0.99115	valid_data-auc:0.71340
# Fold 2 started at Wed May 11 23:40:09 2022
# [23:40:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77438	valid_data-auc:0.68031
# [500]	train-auc:0.99621	valid_data-auc:0.72014
# [532]	train-auc:0.99697	valid_data-auc:0.71970
# Fold 3 started at Wed May 11 23:40:27 2022
# [23:40:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76818	valid_data-auc:0.68512
# [372]	train-auc:0.99103	valid_data-auc:0.72244
# Fold 4 started at Wed May 11 23:40:40 2022
# [23:40:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77427	valid_data-auc:0.67104
# [414]	train-auc:0.99284	valid_data-auc:0.71760
# Fold 5 started at Wed May 11 23:40:53 2022
# [23:40:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77351	valid_data-auc:0.67482
# [378]	train-auc:0.98987	valid_data-auc:0.72193
# CV mean score: 0.7209, std: 0.0031.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:41:08 2022
# [23:41:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77499	valid_data-auc:0.65972
# [392]	train-auc:0.99614	valid_data-auc:0.70447
# Fold 2 started at Wed May 11 23:41:25 2022
# [23:41:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77508	valid_data-auc:0.67023
# [426]	train-auc:0.99674	valid_data-auc:0.71894
# Fold 3 started at Wed May 11 23:41:41 2022
# [23:41:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77258	valid_data-auc:0.65838
# [390]	train-auc:0.99530	valid_data-auc:0.70673
# Fold 4 started at Wed May 11 23:41:55 2022
# [23:41:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77550	valid_data-auc:0.65816
# [365]	train-auc:0.99457	valid_data-auc:0.70851
# Fold 5 started at Wed May 11 23:42:08 2022
# [23:42:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77680	valid_data-auc:0.66574
# [411]	train-auc:0.99562	valid_data-auc:0.71692
# CV mean score: 0.7151, std: 0.0055.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:42:27 2022
# [23:42:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88037	valid_data-auc:0.83503
# [450]	train-auc:0.99653	valid_data-auc:0.86114
# Fold 2 started at Wed May 11 23:42:42 2022
# [23:42:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88327	valid_data-auc:0.83794
# [372]	train-auc:0.99250	valid_data-auc:0.86063
# Fold 3 started at Wed May 11 23:42:55 2022
# [23:42:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88396	valid_data-auc:0.83038
# [370]	train-auc:0.99327	valid_data-auc:0.85470
# Fold 4 started at Wed May 11 23:43:08 2022
# [23:43:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87979	valid_data-auc:0.83652
# [387]	train-auc:0.99352	valid_data-auc:0.86029
# Fold 5 started at Wed May 11 23:43:21 2022
# [23:43:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88283	valid_data-auc:0.83550
# [373]	train-auc:0.99305	valid_data-auc:0.86367
# CV mean score: 0.8616, std: 0.0026.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:43:35 2022
# [23:43:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88408	valid_data-auc:0.82766
# [386]	train-auc:0.99521	valid_data-auc:0.85256
# Fold 2 started at Wed May 11 23:43:49 2022
# [23:43:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88652	valid_data-auc:0.83030
# [407]	train-auc:0.99548	valid_data-auc:0.85482
# Fold 3 started at Wed May 11 23:44:04 2022
# [23:44:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88425	valid_data-auc:0.82132
# [346]	train-auc:0.99240	valid_data-auc:0.84970
# Fold 4 started at Wed May 11 23:44:16 2022
# [23:44:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88204	valid_data-auc:0.82561
# [359]	train-auc:0.99240	valid_data-auc:0.85325
# Fold 5 started at Wed May 11 23:44:29 2022
# [23:44:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88264	valid_data-auc:0.83542
# [284]	train-auc:0.98766	valid_data-auc:0.85814
# CV mean score: 0.8555, std: 0.0023.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:44:42 2022
# [23:44:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88571	valid_data-auc:0.83020
# [410]	train-auc:0.99687	valid_data-auc:0.85922
# Fold 2 started at Wed May 11 23:44:56 2022
# [23:44:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88482	valid_data-auc:0.82522
# [500]	train-auc:0.99825	valid_data-auc:0.85927
# [534]	train-auc:0.99863	valid_data-auc:0.85904
# Fold 3 started at Wed May 11 23:45:13 2022
# [23:45:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88431	valid_data-auc:0.82720
# [447]	train-auc:0.99757	valid_data-auc:0.85415
# Fold 4 started at Wed May 11 23:45:29 2022
# [23:45:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88527	valid_data-auc:0.82739
# [469]	train-auc:0.99807	valid_data-auc:0.86043
# Fold 5 started at Wed May 11 23:45:45 2022
# [23:45:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88707	valid_data-auc:0.83689
# [500]	train-auc:0.99859	valid_data-auc:0.86472
# [514]	train-auc:0.99871	valid_data-auc:0.86458
# CV mean score: 0.8606, std: 0.0034.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:46:05 2022
# [23:46:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87929	valid_data-auc:0.83247
# [440]	train-auc:0.99805	valid_data-auc:0.85774
# Fold 2 started at Wed May 11 23:46:20 2022
# [23:46:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88347	valid_data-auc:0.83215
# [387]	train-auc:0.99661	valid_data-auc:0.85936
# Fold 3 started at Wed May 11 23:46:33 2022
# [23:46:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88310	valid_data-auc:0.83333
# [437]	train-auc:0.99795	valid_data-auc:0.85520
# Fold 4 started at Wed May 11 23:46:49 2022
# [23:46:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88412	valid_data-auc:0.83368
# [396]	train-auc:0.99686	valid_data-auc:0.86241
# Fold 5 started at Wed May 11 23:47:03 2022
# [23:47:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88346	valid_data-auc:0.84038
# [400]	train-auc:0.99720	valid_data-auc:0.86517
# CV mean score: 0.8613, std: 0.0035.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:47:19 2022
# [23:47:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77547	valid_data-auc:0.65496
# [397]	train-auc:0.99141	valid_data-auc:0.70629
# Fold 2 started at Wed May 11 23:47:33 2022
# [23:47:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77516	valid_data-auc:0.65699
# [423]	train-auc:0.99268	valid_data-auc:0.71281
# Fold 3 started at Wed May 11 23:47:48 2022
# [23:47:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77881	valid_data-auc:0.65762
# [368]	train-auc:0.98930	valid_data-auc:0.70544
# Fold 4 started at Wed May 11 23:48:04 2022
# [23:48:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77954	valid_data-auc:0.64616
# [461]	train-auc:0.99369	valid_data-auc:0.70579
# Fold 5 started at Wed May 11 23:48:20 2022
# [23:48:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76607	valid_data-auc:0.66890
# [376]	train-auc:0.98844	valid_data-auc:0.72503
# CV mean score: 0.7148, std: 0.0074.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:48:35 2022
# [23:48:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88454	valid_data-auc:0.82591
# [388]	train-auc:0.99784	valid_data-auc:0.85943
# Fold 2 started at Wed May 11 23:48:50 2022
# [23:48:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88328	valid_data-auc:0.83623
# [445]	train-auc:0.99850	valid_data-auc:0.86367
# Fold 3 started at Wed May 11 23:49:08 2022
# [23:49:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88156	valid_data-auc:0.82850
# [470]	train-auc:0.99895	valid_data-auc:0.85704
# Fold 4 started at Wed May 11 23:49:27 2022
# [23:49:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88091	valid_data-auc:0.83843
# [412]	train-auc:0.99793	valid_data-auc:0.86573
# Fold 5 started at Wed May 11 23:49:42 2022
# [23:49:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88255	valid_data-auc:0.84164
# [500]	train-auc:0.99915	valid_data-auc:0.86565
# [501]	train-auc:0.99916	valid_data-auc:0.86565
# CV mean score: 0.8635, std: 0.0031.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:50:02 2022
# [23:50:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77249	valid_data-auc:0.66245
# [410]	train-auc:0.99226	valid_data-auc:0.70431
# Fold 2 started at Wed May 11 23:50:15 2022
# [23:50:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76720	valid_data-auc:0.66450
# [451]	train-auc:0.99345	valid_data-auc:0.71459
# Fold 3 started at Wed May 11 23:50:30 2022
# [23:50:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77400	valid_data-auc:0.66679
# [345]	train-auc:0.98761	valid_data-auc:0.71820
# Fold 4 started at Wed May 11 23:50:42 2022
# [23:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76494	valid_data-auc:0.66807
# [392]	train-auc:0.99032	valid_data-auc:0.70993
# Fold 5 started at Wed May 11 23:50:55 2022
# [23:50:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76541	valid_data-auc:0.67075
# [500]	train-auc:0.99581	valid_data-auc:0.72659
# [504]	train-auc:0.99587	valid_data-auc:0.72649
# CV mean score: 0.7175, std: 0.0077.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:51:14 2022
# [23:51:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76855	valid_data-auc:0.65362
# [424]	train-auc:0.99031	valid_data-auc:0.69779
# Fold 2 started at Wed May 11 23:51:31 2022
# [23:51:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77003	valid_data-auc:0.67021
# [342]	train-auc:0.98282	valid_data-auc:0.70391
# Fold 3 started at Wed May 11 23:51:43 2022
# [23:51:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76501	valid_data-auc:0.67131
# [378]	train-auc:0.98791	valid_data-auc:0.70652
# Fold 4 started at Wed May 11 23:51:56 2022
# [23:51:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76806	valid_data-auc:0.64642
# [375]	train-auc:0.98627	valid_data-auc:0.70258
# Fold 5 started at Wed May 11 23:52:11 2022
# [23:52:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76719	valid_data-auc:0.66079
# [356]	train-auc:0.98471	valid_data-auc:0.71009
# CV mean score: 0.7079, std: 0.0044.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:52:25 2022
# [23:52:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87984	valid_data-auc:0.82740
# [400]	train-auc:0.99632	valid_data-auc:0.85014
# Fold 2 started at Wed May 11 23:52:39 2022
# [23:52:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88502	valid_data-auc:0.82981
# [396]	train-auc:0.99519	valid_data-auc:0.85792
# Fold 3 started at Wed May 11 23:52:54 2022
# [23:52:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88540	valid_data-auc:0.82860
# [363]	train-auc:0.99412	valid_data-auc:0.85213
# Fold 4 started at Wed May 11 23:53:08 2022
# [23:53:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88290	valid_data-auc:0.82994
# [432]	train-auc:0.99642	valid_data-auc:0.85720
# Fold 5 started at Wed May 11 23:53:23 2022
# [23:53:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88234	valid_data-auc:0.83051
# [392]	train-auc:0.99540	valid_data-auc:0.85583
# CV mean score: 0.8562, std: 0.0027.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Wed May 11 23:53:38 2022
# [23:53:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87935	valid_data-auc:0.82331
# [482]	train-auc:0.99709	valid_data-auc:0.85244
# Fold 2 started at Wed May 11 23:53:56 2022
# [23:53:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ...
#
#
# [0]	train-auc:0.81561	valid_data-auc:0.71936
# [395]	train-auc:0.99311	valid_data-auc:0.76608
# CV mean score: 0.7650, std: 0.0023.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 01:53:04 2022
# [01:53:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88103	valid_data-auc:0.83321
# [339]	train-auc:0.99319	valid_data-auc:0.85931
# Fold 2 started at Thu May 12 01:53:42 2022
# [01:53:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88544	valid_data-auc:0.83598
# [485]	train-auc:0.99800	valid_data-auc:0.86025
# Fold 3 started at Thu May 12 01:54:32 2022
# [01:54:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88379	valid_data-auc:0.83041
# [395]	train-auc:0.99578	valid_data-auc:0.85280
# Fold 4 started at Thu May 12 01:55:19 2022
# [01:55:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88508	valid_data-auc:0.83437
# [384]	train-auc:0.99489	valid_data-auc:0.85840
# Fold 5 started at Thu May 12 01:55:59 2022
# [01:55:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88426	valid_data-auc:0.83705
# [392]	train-auc:0.99528	valid_data-auc:0.86186
# CV mean score: 0.8603, std: 0.0029.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 01:56:46 2022
# [01:56:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87554	valid_data-auc:0.81756
# [338]	train-auc:0.98445	valid_data-auc:0.83756
# Fold 2 started at Thu May 12 01:57:26 2022
# [01:57:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87717	valid_data-auc:0.82281
# [307]	train-auc:0.98036	valid_data-auc:0.84257
# Fold 3 started at Thu May 12 01:58:02 2022
# [01:58:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87473	valid_data-auc:0.82364
# [291]	train-auc:0.97950	valid_data-auc:0.83959
# Fold 4 started at Thu May 12 01:58:32 2022
# [01:58:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87419	valid_data-auc:0.82445
# [326]	train-auc:0.98247	valid_data-auc:0.84253
# Fold 5 started at Thu May 12 01:59:10 2022
# [01:59:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87518	valid_data-auc:0.83164
# [241]	train-auc:0.97449	valid_data-auc:0.84884
# CV mean score: 0.8442, std: 0.0039.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 01:59:43 2022
# [01:59:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88531	valid_data-auc:0.82691
# [379]	train-auc:0.99674	valid_data-auc:0.85461
# Fold 2 started at Thu May 12 02:00:26 2022
# [02:00:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88334	valid_data-auc:0.82874
# [424]	train-auc:0.99733	valid_data-auc:0.85951
# Fold 3 started at Thu May 12 02:01:12 2022
# [02:01:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88305	valid_data-auc:0.82699
# [364]	train-auc:0.99550	valid_data-auc:0.85193
# Fold 4 started at Thu May 12 02:01:58 2022
# [02:01:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88402	valid_data-auc:0.82752
# [354]	train-auc:0.99482	valid_data-auc:0.85656
# Fold 5 started at Thu May 12 02:02:42 2022
# [02:02:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88458	valid_data-auc:0.83549
# [377]	train-auc:0.99560	valid_data-auc:0.86076
# CV mean score: 0.8580, std: 0.0031.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 02:03:26 2022
# [02:03:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81642	valid_data-auc:0.71933
# [387]	train-auc:0.98891	valid_data-auc:0.75795
# Fold 2 started at Thu May 12 02:04:13 2022
# [02:04:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80836	valid_data-auc:0.71554
# [500]	train-auc:0.99412	valid_data-auc:0.76809
# [581]	train-auc:0.99645	valid_data-auc:0.76652
# Fold 3 started at Thu May 12 02:05:14 2022
# [02:05:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81293	valid_data-auc:0.71825
# [341]	train-auc:0.98404	valid_data-auc:0.75994
# Fold 4 started at Thu May 12 02:05:52 2022
# [02:05:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81796	valid_data-auc:0.71486
# [385]	train-auc:0.98640	valid_data-auc:0.75894
# Fold 5 started at Thu May 12 02:06:38 2022
# [02:06:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81435	valid_data-auc:0.73487
# [342]	train-auc:0.98441	valid_data-auc:0.77173
# CV mean score: 0.7661, std: 0.0048.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 02:07:15 2022
# [02:07:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81480	valid_data-auc:0.71211
# [365]	train-auc:0.99369	valid_data-auc:0.76264
# Fold 2 started at Thu May 12 02:07:58 2022
# [02:07:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81499	valid_data-auc:0.71173
# [335]	train-auc:0.99247	valid_data-auc:0.76767
# Fold 3 started at Thu May 12 02:08:38 2022
# [02:08:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81624	valid_data-auc:0.70922
# [341]	train-auc:0.99178	valid_data-auc:0.76179
# Fold 4 started at Thu May 12 02:09:26 2022
# [02:09:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81567	valid_data-auc:0.71308
# [305]	train-auc:0.98875	valid_data-auc:0.76277
# Fold 5 started at Thu May 12 02:10:08 2022
# [02:10:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81292	valid_data-auc:0.72065
# [354]	train-auc:0.99213	valid_data-auc:0.77130
# CV mean score: 0.7675, std: 0.0037.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 02:10:51 2022
# [02:10:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87921	valid_data-auc:0.82831
# [420]	train-auc:0.99468	valid_data-auc:0.85592
# Fold 2 started at Thu May 12 02:11:37 2022
# [02:11:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87959	valid_data-auc:0.83055

# %%
seeds = [11]
f = "./output/15fea_res/test2.txt"
a = 10000
history  = []
with open(f,"w") as file:   #”w"代表着每次运行都覆盖内容
    for i in range(a):
        result = sample(fea_box,15)
        if sorted(result) in history: continue
        history.append(sorted(result))
        
        train = reduce_mem_usage(original_train[['CUST_UID','LABEL'] + result])
        test = reduce_mem_usage(original_test[['CUST_UID'] + result])
        n_fold = 5
        #folds = TimeSeriesSplit(n_splits=n_fold)
        folds = KFold(n_splits=5)
        X = train.sort_values('CUST_UID').drop(['LABEL', 'CUST_UID'], axis=1)
        y = train.sort_values('CUST_UID')['LABEL']
        X_test = test.drop(['CUST_UID'], axis=1)

        def clean_inf_nan(df):
            return df.replace([np.inf, -np.inf], np.nan)   

        # Cleaning infinite values to NaN
        X = clean_inf_nan(X)
        X_test = clean_inf_nan(X_test )


        print(len(X.columns))
        print(X.shape,X_test.shape)#266维度7966

        averag = 'rank'
        model_name = 'xgb'
        xgb_params = {'eta': 0.03,
                    'max_depth': 11,#5
                    'subsample': 0.85,
                    'objective': 'binary:logistic',
                    'eval_metric': 'auc',
                    'seed': 11,
                    'silent': True,
                    'nthread': -1,
                    'tree_method': 'gpu_hist'}
        result_dict_xgb = train_model_classification(X=X, X_test=X_test, y=y, params=xgb_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
                                                            verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)

        file.write(str(sorted(result)) + str(np.mean(result_dict_xgb['scores']))  + " "+"\n")
# Out:
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:40:34 2022
# [08:40:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81727	valid_data-auc:0.71948
# [400]	train-auc:0.99194	valid_data-auc:0.75575
# Fold 2 started at Thu May 12 08:40:50 2022
# [08:40:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80529	valid_data-auc:0.72353
# [412]	train-auc:0.99203	valid_data-auc:0.77210
# Fold 3 started at Thu May 12 08:41:05 2022
# [08:41:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81381	valid_data-auc:0.71656
# [378]	train-auc:0.99155	valid_data-auc:0.75963
# Fold 4 started at Thu May 12 08:41:18 2022
# [08:41:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81197	valid_data-auc:0.71022
# [351]	train-auc:0.98773	valid_data-auc:0.75623
# Fold 5 started at Thu May 12 08:41:31 2022
# [08:41:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81318	valid_data-auc:0.72928
# [365]	train-auc:0.98902	valid_data-auc:0.77601
# CV mean score: 0.7667, std: 0.0082.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:41:46 2022
# [08:41:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88050	valid_data-auc:0.82519
# [455]	train-auc:0.99764	valid_data-auc:0.85257
# Fold 2 started at Thu May 12 08:42:02 2022
# [08:42:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88309	valid_data-auc:0.83284
# [475]	train-auc:0.99780	valid_data-auc:0.85503
# Fold 3 started at Thu May 12 08:42:21 2022
# [08:42:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88221	valid_data-auc:0.82552
# [398]	train-auc:0.99608	valid_data-auc:0.85150
# Fold 4 started at Thu May 12 08:42:36 2022
# [08:42:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88161	valid_data-auc:0.82994
# [383]	train-auc:0.99556	valid_data-auc:0.85538
# Fold 5 started at Thu May 12 08:42:50 2022
# [08:42:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88420	valid_data-auc:0.83225
# [454]	train-auc:0.99736	valid_data-auc:0.86084
# CV mean score: 0.8565, std: 0.0034.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:43:10 2022
# [08:43:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88366	valid_data-auc:0.83301
# [419]	train-auc:0.99494	valid_data-auc:0.85914
# Fold 2 started at Thu May 12 08:43:24 2022
# [08:43:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88402	valid_data-auc:0.83523
# [390]	train-auc:0.99302	valid_data-auc:0.86057
# Fold 3 started at Thu May 12 08:43:37 2022
# [08:43:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88669	valid_data-auc:0.83396
# [379]	train-auc:0.99328	valid_data-auc:0.85608
# Fold 4 started at Thu May 12 08:43:51 2022
# [08:43:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88386	valid_data-auc:0.83537
# [413]	train-auc:0.99402	valid_data-auc:0.86262
# Fold 5 started at Thu May 12 08:44:07 2022
# [08:44:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88759	valid_data-auc:0.83691
# [386]	train-auc:0.99365	valid_data-auc:0.86443
# CV mean score: 0.8620, std: 0.0028.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:44:22 2022
# [08:44:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80824	valid_data-auc:0.71583
# [366]	train-auc:0.98347	valid_data-auc:0.75705
# Fold 2 started at Thu May 12 08:44:35 2022
# [08:44:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80502	valid_data-auc:0.71701
# [451]	train-auc:0.98873	valid_data-auc:0.77070
# Fold 3 started at Thu May 12 08:44:52 2022
# [08:44:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80280	valid_data-auc:0.71960
# [357]	train-auc:0.98185	valid_data-auc:0.76612
# Fold 4 started at Thu May 12 08:45:04 2022
# [08:45:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80543	valid_data-auc:0.71369
# [389]	train-auc:0.98490	valid_data-auc:0.76040
# Fold 5 started at Thu May 12 08:45:17 2022
# [08:45:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80666	valid_data-auc:0.71919
# [410]	train-auc:0.98711	valid_data-auc:0.77139
# CV mean score: 0.7674, std: 0.0058.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:45:35 2022
# [08:45:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.73703	valid_data-auc:0.64206
# [367]	train-auc:0.96472	valid_data-auc:0.68536
# Fold 2 started at Thu May 12 08:45:47 2022
# [08:45:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.73924	valid_data-auc:0.64615
# [388]	train-auc:0.96918	valid_data-auc:0.68653
# Fold 3 started at Thu May 12 08:45:59 2022
# [08:45:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.73563	valid_data-auc:0.65383
# [386]	train-auc:0.96716	valid_data-auc:0.68265
# Fold 4 started at Thu May 12 08:46:11 2022
# [08:46:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.73932	valid_data-auc:0.64720
# [366]	train-auc:0.96511	valid_data-auc:0.68212
# Fold 5 started at Thu May 12 08:46:23 2022
# [08:46:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.73068	valid_data-auc:0.65775
# [362]	train-auc:0.96557	valid_data-auc:0.69400
# CV mean score: 0.6901, std: 0.0044.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:46:38 2022
# [08:46:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80714	valid_data-auc:0.72108
# [375]	train-auc:0.98481	valid_data-auc:0.75696
# Fold 2 started at Thu May 12 08:46:51 2022
# [08:46:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80792	valid_data-auc:0.71299
# [473]	train-auc:0.99161	valid_data-auc:0.76181
# Fold 3 started at Thu May 12 08:47:08 2022
# [08:47:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81264	valid_data-auc:0.71110
# [361]	train-auc:0.98577	valid_data-auc:0.75771
# Fold 4 started at Thu May 12 08:47:20 2022
# [08:47:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80636	valid_data-auc:0.71251
# [315]	train-auc:0.97845	valid_data-auc:0.75937
# Fold 5 started at Thu May 12 08:47:34 2022
# [08:47:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81107	valid_data-auc:0.71979
# [376]	train-auc:0.98506	valid_data-auc:0.76946
# CV mean score: 0.7636, std: 0.0041.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:47:48 2022
# [08:47:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87523	valid_data-auc:0.82183
# [351]	train-auc:0.98840	valid_data-auc:0.84138
# Fold 2 started at Thu May 12 08:48:00 2022
# [08:48:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87181	valid_data-auc:0.81679
# [371]	train-auc:0.98815	valid_data-auc:0.84471
# Fold 3 started at Thu May 12 08:48:13 2022
# [08:48:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87574	valid_data-auc:0.81789
# [293]	train-auc:0.98157	valid_data-auc:0.84184
# Fold 4 started at Thu May 12 08:48:23 2022
# [08:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87379	valid_data-auc:0.82565
# [314]	train-auc:0.98380	valid_data-auc:0.84470
# Fold 5 started at Thu May 12 08:48:34 2022
# [08:48:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87072	valid_data-auc:0.82971
# [467]	train-auc:0.99391	valid_data-auc:0.85069
# CV mean score: 0.8464, std: 0.0032.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:48:51 2022
# [08:48:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88051	valid_data-auc:0.82006
# [382]	train-auc:0.99411	valid_data-auc:0.84871
# Fold 2 started at Thu May 12 08:49:05 2022
# [08:49:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88387	valid_data-auc:0.82413
# [448]	train-auc:0.99493	valid_data-auc:0.85496
# Fold 3 started at Thu May 12 08:49:21 2022
# [08:49:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88306	valid_data-auc:0.82284
# [410]	train-auc:0.99414	valid_data-auc:0.85071
# Fold 4 started at Thu May 12 08:49:38 2022
# [08:49:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88138	valid_data-auc:0.82888
# [419]	train-auc:0.99402	valid_data-auc:0.85502
# Fold 5 started at Thu May 12 08:49:52 2022
# [08:49:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88186	valid_data-auc:0.83067
# [373]	train-auc:0.99248	valid_data-auc:0.85513
# CV mean score: 0.8547, std: 0.0023.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:50:08 2022
# [08:50:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.82478	valid_data-auc:0.71562
# [496]	train-auc:0.99817	valid_data-auc:0.77195
# Fold 2 started at Thu May 12 08:50:26 2022
# [08:50:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81683	valid_data-auc:0.72213
# [368]	train-auc:0.99422	valid_data-auc:0.77871
# Fold 3 started at Thu May 12 08:50:39 2022
# [08:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81979	valid_data-auc:0.71963
# [407]	train-auc:0.99588	valid_data-auc:0.77167
# Fold 4 started at Thu May 12 08:50:57 2022
# [08:50:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.82348	valid_data-auc:0.71747
# [346]	train-auc:0.99236	valid_data-auc:0.77413
# Fold 5 started at Thu May 12 08:51:10 2022
# [08:51:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81745	valid_data-auc:0.73423
# [444]	train-auc:0.99698	valid_data-auc:0.78193
# CV mean score: 0.7773, std: 0.0036.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:51:28 2022
# [08:51:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80974	valid_data-auc:0.72305
# [440]	train-auc:0.98422	valid_data-auc:0.76861
# Fold 2 started at Thu May 12 08:51:43 2022
# [08:51:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80551	valid_data-auc:0.73346
# [444]	train-auc:0.98399	valid_data-auc:0.77450
# Fold 3 started at Thu May 12 08:51:57 2022
# [08:51:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81542	valid_data-auc:0.71916
# [349]	train-auc:0.97769	valid_data-auc:0.76480
# Fold 4 started at Thu May 12 08:52:10 2022
# [08:52:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81330	valid_data-auc:0.72187
# [341]	train-auc:0.97552	valid_data-auc:0.75899
# Fold 5 started at Thu May 12 08:52:22 2022
# [08:52:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81448	valid_data-auc:0.73729
# [362]	train-auc:0.97754	valid_data-auc:0.77270
# CV mean score: 0.7716, std: 0.0046.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:52:36 2022
# [08:52:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88634	valid_data-auc:0.83322
# [405]	train-auc:0.99866	valid_data-auc:0.85948
# Fold 2 started at Thu May 12 08:52:54 2022
# [08:52:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88511	valid_data-auc:0.83332
# [443]	train-auc:0.99899	valid_data-auc:0.86321
# Fold 3 started at Thu May 12 08:53:10 2022
# [08:53:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88224	valid_data-auc:0.83133
# [451]	train-auc:0.99921	valid_data-auc:0.85648
# Fold 4 started at Thu May 12 08:53:29 2022
# [08:53:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88562	valid_data-auc:0.83282
# [453]	train-auc:0.99916	valid_data-auc:0.86069
# Fold 5 started at Thu May 12 08:53:48 2022
# [08:53:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88636	valid_data-auc:0.83554
# [438]	train-auc:0.99882	valid_data-auc:0.86077
# CV mean score: 0.8613, std: 0.0023.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:54:05 2022
# [08:54:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80464	valid_data-auc:0.71472
# [402]	train-auc:0.98765	valid_data-auc:0.75764
# Fold 2 started at Thu May 12 08:54:19 2022
# [08:54:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80361	valid_data-auc:0.71801
# [468]	train-auc:0.98961	valid_data-auc:0.75961
# Fold 3 started at Thu May 12 08:54:34 2022
# [08:54:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80108	valid_data-auc:0.71350
# [327]	train-auc:0.97944	valid_data-auc:0.76094
# Fold 4 started at Thu May 12 08:54:45 2022
# [08:54:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80665	valid_data-auc:0.70616
# [364]	train-auc:0.98212	valid_data-auc:0.75385
# Fold 5 started at Thu May 12 08:54:57 2022
# [08:54:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80312	valid_data-auc:0.72143
# [366]	train-auc:0.98318	valid_data-auc:0.76270
# CV mean score: 0.7611, std: 0.0027.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:55:11 2022
# [08:55:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80457	valid_data-auc:0.70960
# [401]	train-auc:0.98561	valid_data-auc:0.74114
# Fold 2 started at Thu May 12 08:55:25 2022
# [08:55:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.79987	valid_data-auc:0.71593
# [404]	train-auc:0.98372	valid_data-auc:0.76109
# Fold 3 started at Thu May 12 08:55:39 2022
# [08:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80160	valid_data-auc:0.71249
# [331]	train-auc:0.97783	valid_data-auc:0.75239
# Fold 4 started at Thu May 12 08:55:51 2022
# [08:55:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80382	valid_data-auc:0.70717
# [405]	train-auc:0.98413	valid_data-auc:0.74611
# Fold 5 started at Thu May 12 08:56:06 2022
# [08:56:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.79923	valid_data-auc:0.72718
# [376]	train-auc:0.98202	valid_data-auc:0.76602
# CV mean score: 0.7559, std: 0.0086.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:56:22 2022
# [08:56:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81369	valid_data-auc:0.72828
# [418]	train-auc:0.99132	valid_data-auc:0.77273
# Fold 2 started at Thu May 12 08:56:39 2022
# [08:56:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81847	valid_data-auc:0.72307
# [500]	train-auc:0.99558	valid_data-auc:0.77413
# [524]	train-auc:0.99638	valid_data-auc:0.77377
# Fold 3 started at Thu May 12 08:56:56 2022
# [08:56:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81528	valid_data-auc:0.72730
# [379]	train-auc:0.98863	valid_data-auc:0.77444
# Fold 4 started at Thu May 12 08:57:09 2022
# [08:57:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81387	valid_data-auc:0.72805
# [330]	train-auc:0.98411	valid_data-auc:0.76977
# Fold 5 started at Thu May 12 08:57:21 2022
# [08:57:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81214	valid_data-auc:0.72787
# [354]	train-auc:0.98658	valid_data-auc:0.77843
# CV mean score: 0.7761, std: 0.0026.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:57:35 2022
# [08:57:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76000	valid_data-auc:0.66881
# [353]	train-auc:0.98076	valid_data-auc:0.70703
# Fold 2 started at Thu May 12 08:57:48 2022
# [08:57:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76570	valid_data-auc:0.66654
# [403]	train-auc:0.98711	valid_data-auc:0.70641
# Fold 3 started at Thu May 12 08:58:01 2022
# [08:58:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76186	valid_data-auc:0.66027
# [380]	train-auc:0.98524	valid_data-auc:0.70920
# Fold 4 started at Thu May 12 08:58:14 2022
# [08:58:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76417	valid_data-auc:0.65433
# [293]	train-auc:0.97026	valid_data-auc:0.70036
# Fold 5 started at Thu May 12 08:58:24 2022
# [08:58:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.76311	valid_data-auc:0.66763
# [360]	train-auc:0.98355	valid_data-auc:0.71476
# CV mean score: 0.7106, std: 0.0053.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:58:39 2022
# [08:58:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88008	valid_data-auc:0.82870
# [338]	train-auc:0.98769	valid_data-auc:0.85061
# Fold 2 started at Thu May 12 08:58:50 2022
# [08:58:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88062	valid_data-auc:0.82570
# [396]	train-auc:0.99143	valid_data-auc:0.85482
# Fold 3 started at Thu May 12 08:59:04 2022
# [08:59:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88186	valid_data-auc:0.82566
# [388]	train-auc:0.99040	valid_data-auc:0.84886
# Fold 4 started at Thu May 12 08:59:16 2022
# [08:59:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88055	valid_data-auc:0.82978
# [397]	train-auc:0.99119	valid_data-auc:0.85255
# Fold 5 started at Thu May 12 08:59:30 2022
# [08:59:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87962	valid_data-auc:0.83175
# [368]	train-auc:0.98986	valid_data-auc:0.85907
# CV mean score: 0.8546, std: 0.0035.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 08:59:47 2022
# [08:59:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87760	valid_data-auc:0.82628
# [313]	train-auc:0.98572	valid_data-auc:0.84861
# Fold 2 started at Thu May 12 08:59:58 2022
# [08:59:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87965	valid_data-auc:0.82839
# [382]	train-auc:0.98918	valid_data-auc:0.85187
# Fold 3 started at Thu May 12 09:00:10 2022
# ...
# [14:13:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87599	valid_data-auc:0.82592
# [359]	train-auc:0.98803	valid_data-auc:0.85112
# Fold 2 started at Thu May 12 14:13:25 2022
# [14:13:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87746	valid_data-auc:0.82186
# [382]	train-auc:0.98805	valid_data-auc:0.85351
# Fold 3 started at Thu May 12 14:13:37 2022
# [14:13:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87956	valid_data-auc:0.81921
# [482]	train-auc:0.99398	valid_data-auc:0.85014
# Fold 4 started at Thu May 12 14:13:52 2022
# [14:13:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87667	valid_data-auc:0.83516
# [335]	train-auc:0.98453	valid_data-auc:0.85637
# Fold 5 started at Thu May 12 14:14:03 2022
# [14:14:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.87778	valid_data-auc:0.83223
# [380]	train-auc:0.98900	valid_data-auc:0.85947
# CV mean score: 0.8557, std: 0.0033.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 14:14:18 2022
# [14:14:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77917	valid_data-auc:0.67810
# [500]	train-auc:0.99806	valid_data-auc:0.71641
# Fold 2 started at Thu May 12 14:14:35 2022
# [14:14:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.78484	valid_data-auc:0.68449
# [500]	train-auc:0.99804	valid_data-auc:0.72149
# [524]	train-auc:0.99841	valid_data-auc:0.72146
# Fold 3 started at Thu May 12 14:14:52 2022
# [14:14:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.77924	valid_data-auc:0.66553
# [386]	train-auc:0.99555	valid_data-auc:0.71914
# Fold 4 started at Thu May 12 14:15:06 2022
# [14:15:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.78135	valid_data-auc:0.67053
# [387]	train-auc:0.99503	valid_data-auc:0.71681
# Fold 5 started at Thu May 12 14:15:20 2022
# [14:15:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.78356	valid_data-auc:0.68264
# [367]	train-auc:0.99364	valid_data-auc:0.72524
# CV mean score: 0.7220, std: 0.0030.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 14:15:35 2022
# [14:15:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88258	valid_data-auc:0.82789
# [457]	train-auc:0.99601	valid_data-auc:0.85672
# Fold 2 started at Thu May 12 14:15:50 2022
# [14:15:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88453	valid_data-auc:0.83033
# [500]	train-auc:0.99745	valid_data-auc:0.85925
# [509]	train-auc:0.99763	valid_data-auc:0.85917
# Fold 3 started at Thu May 12 14:16:06 2022
# [14:16:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88110	valid_data-auc:0.83066
# [329]	train-auc:0.99007	valid_data-auc:0.84900
# Fold 4 started at Thu May 12 14:16:17 2022
# [14:16:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88165	valid_data-auc:0.82761
# [356]	train-auc:0.99116	valid_data-auc:0.85325
# Fold 5 started at Thu May 12 14:16:29 2022
# [14:16:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.88555	valid_data-auc:0.83537
# [356]	train-auc:0.99179	valid_data-auc:0.86101
# CV mean score: 0.8573, std: 0.0041.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 14:16:43 2022
# [14:16:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80936	valid_data-auc:0.72782
# [412]	train-auc:0.97465	valid_data-auc:0.76328
# Fold 2 started at Thu May 12 14:16:57 2022
# [14:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80037	valid_data-auc:0.73046
# [333]	train-auc:0.96609	valid_data-auc:0.77377
# Fold 3 started at Thu May 12 14:17:08 2022
# [14:17:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80411	valid_data-auc:0.72844
# [365]	train-auc:0.96902	valid_data-auc:0.76815
# Fold 4 started at Thu May 12 14:17:19 2022
# [14:17:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80706	valid_data-auc:0.71882
# [294]	train-auc:0.96088	valid_data-auc:0.76193
# Fold 5 started at Thu May 12 14:17:32 2022
# [14:17:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.80205	valid_data-auc:0.72980
# [326]	train-auc:0.96476	valid_data-auc:0.77254
# CV mean score: 0.7701, std: 0.0043.
# Mem. usage decreased to  8.01 Mb (0.0% reduction)
# Mem. usage decreased to  2.39 Mb (0.0% reduction)
# 15
# (40000, 15) (12000, 15)
# Fold 1 started at Thu May 12 14:17:44 2022
# [14:17:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.82350	valid_data-auc:0.71621
# [385]	train-auc:0.99492	valid_data-auc:0.77355
# Fold 2 started at Thu May 12 14:17:59 2022
# [14:17:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.82179	valid_data-auc:0.73154
# [460]	train-auc:0.99680	valid_data-auc:0.77982
# Fold 3 started at Thu May 12 14:18:15 2022
# [14:18:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.81920	valid_data-auc:0.72975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7f11c9f09671> in <module>
#      41                     'tree_method': 'gpu_hist'}
#      42         result_dict_xgb = train_model_classification(X=X, X_test=X_test, y=y, params=xgb_params, folds=folds, model_type=model_name, eval_metric='auc', plot_feature_importance=False,
# ---> 43                                                             verbose=500, early_stopping_rounds=200, n_estimators=5000, averaging=averag)
#      44
#      45         file.write(str(sorted(result)) + str(np.mean(result_dict_xgb['scores']))  + " "+"\n")
#
# <ipython-input-4-5e0584766d9c> in train_model_classification(X, X_test, y, params, folds, model_type, eval_metric, columns, plot_feature_importance, model, verbose, early_stopping_rounds, n_estimators, splits, n_folds, averaging, n_jobs)
#     268
#     269             watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
# --> 270             model = xgb.train(dtrain=train_data, num_boost_round=n_estimators, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=verbose, params=params)
#     271             y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
#     272             y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     530         for k, arg in zip(sig.parameters, args):
#     531             kwargs[k] = arg
# --> 532         return f(**kwargs)
#     533
#     534     return inner_f
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179         if cb_container.before_iteration(bst, i, dtrain, evals):
#     180             break
# --> 181         bst.update(dtrain, i, obj)
#     182         if cb_container.after_iteration(bst, i, dtrain, evals):
#     183             break
#
# D:\SoftInstall\Anaconda3\envs\pytorch\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1733             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1734                                                     ctypes.c_int(iteration),
# -> 1735                                                     dtrain.handle))
#    1736         else:
#    1737             pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
