# %%
import os
import pandas as pd
root_dir = os.path.abspath("./data/")
train_info_path = os.path.join(root_dir,"train.xlsx")
test_info_path = os.path.join(root_dir,"test_A榜.xlsx")
train_info=pd.read_excel("./data/train.xlsx",engine='openpyxl')
test_info = pd.read_excel("./data/test_A榜.xlsx",engine='openpyxl')

# %%
print(train_info.count(),test_info.count())
print(train_info.shape,test_info.shape)
# Out:
# CUST_UID                                   40000
# LABEL                                      40000
# AGN_CNT_RCT_12_MON                         40000
# ICO_CUR_MON_ACM_TRX_TM                     40000
# NB_RCT_3_MON_LGN_TMS_AGV                   40000
# AGN_CUR_YEAR_AMT                           40000
# AGN_CUR_YEAR_WAG_AMT                       40000
# AGN_AGR_LATEST_AGN_AMT                     40000
# ICO_CUR_MON_ACM_TRX_AMT                    40000
# COUNTER_CUR_YEAR_CNT_AMT                   40000
# PUB_TO_PRV_TRX_AMT_CUR_YEAR                40000
# MON_12_EXT_SAM_TRSF_IN_AMT                 40000
# MON_12_EXT_SAM_TRSF_OUT_AMT                40000
# MON_12_EXT_SAM_NM_TRSF_OUT_CNT             40000
# MON_12_EXT_SAM_AMT                         40000
# CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT           40000
# CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT          40000
# MON_12_CUST_CNT_PTY_ID                     17170
# MON_12_TRX_AMT_MAX_AMT_PCTT                40000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
f,ax=plt.subplots(1,2,figsize=(18,8))
train_info['LABEL'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('LABEL')
ax[0].set_ylabel('')
sns.countplot('LABEL',data=train_info,ax=ax[1])
ax[1].set_title('LABEL')
plt.show()
# Out:
# D:\software_new\anaconda\conda\envs\torch\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train_info.head()
# Out:
#                            CUST_UID  LABEL AGN_CNT_RCT_12_MON  \
# 0  2a171d461bf24a739b804c2843ad4f6e      0                  ?
# 1  c58d5848d18548e297963c2d9e092699      0               2282
# 2  74e6d8179e784a039bcb5a722014f4a4      0                  ?
# 3  1b6a8be2c2e34de09ca00d71470ec180      1                  ?
# 4  1974b5e0440a41128a416a8cdc8a7c16      1                  ?
#
#   ICO_CUR_MON_ACM_TRX_TM NB_RCT_3_MON_LGN_TMS_AGV AGN_CUR_YEAR_AMT  \
# 0                     72                    425.3                ?
# 1                    222                        ?       11776572.4
# 2                      2                        ?                ?
# 3                      ?                       22                ?
# 4                      ?                        ?                ?
#
#   AGN_CUR_YEAR_WAG_AMT AGN_AGR_LATEST_AGN_AMT ICO_CUR_MON_ACM_TRX_AMT  \
# 0                    ?                      ?              25879985.3
# ...

# %%
train_info.replace({'?':None},inplace =True)

# %%
train_info.head()
# Out:
#                            CUST_UID  LABEL  AGN_CNT_RCT_12_MON  \
# 0  2a171d461bf24a739b804c2843ad4f6e      0                 NaN
# 1  c58d5848d18548e297963c2d9e092699      0              2282.0
# 2  74e6d8179e784a039bcb5a722014f4a4      0                 NaN
# 3  1b6a8be2c2e34de09ca00d71470ec180      1                 NaN
# 4  1974b5e0440a41128a416a8cdc8a7c16      1                 NaN
#
#    ICO_CUR_MON_ACM_TRX_TM  NB_RCT_3_MON_LGN_TMS_AGV  AGN_CUR_YEAR_AMT  \
# 0                    72.0                     425.3               NaN
# 1                   222.0                       NaN        11776572.4
# 2                     2.0                       NaN               NaN
# 3                     NaN                      22.0               NaN
# 4                     NaN                       NaN               NaN
#
#    AGN_CUR_YEAR_WAG_AMT  AGN_AGR_LATEST_AGN_AMT  ICO_CUR_MON_ACM_TRX_AMT  \
# 0                   NaN                     NaN               25879985.3
# ...

# %%
train_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 51 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CUST_UID                                 40000 non-null  object
#  1   LABEL                                    40000 non-null  int64
#  2   AGN_CNT_RCT_12_MON                       18592 non-null  float64
#  3   ICO_CUR_MON_ACM_TRX_TM                   36497 non-null  float64
#  4   NB_RCT_3_MON_LGN_TMS_AGV                 36185 non-null  float64
#  5   AGN_CUR_YEAR_AMT                         17459 non-null  float64
#  6   AGN_CUR_YEAR_WAG_AMT                     12015 non-null  float64
#  7   AGN_AGR_LATEST_AGN_AMT                   20407 non-null  float64
#  8   ICO_CUR_MON_ACM_TRX_AMT                  36497 non-null  float64
#  9   COUNTER_CUR_YEAR_CNT_AMT                 39054 non-null  float64
# ...

# %%
train_info.describe()
# Out:
#               LABEL  AGN_CNT_RCT_12_MON  ICO_CUR_MON_ACM_TRX_TM  \
# count  40000.000000        1.859200e+04            3.649700e+04
# mean       0.250000        2.999511e+04            5.751507e+02
# std        0.433018        1.058966e+06            1.195054e+04
# min        0.000000        2.000000e+00            2.000000e+00
# 25%        0.000000        6.720000e+02            2.200000e+01
# 50%        0.000000        2.472000e+03            9.200000e+01
# 75%        0.250000        8.772000e+03            3.320000e+02
# max        1.000000        1.428082e+08            1.795242e+06
#
#        NB_RCT_3_MON_LGN_TMS_AGV  AGN_CUR_YEAR_AMT  AGN_CUR_YEAR_WAG_AMT  \
# count              36185.000000      1.745900e+04          1.201500e+04
# mean                 343.579107      1.127407e+08          9.023501e+07
# std                  769.131402      1.455135e+09          1.514860e+09
# min                    2.000000      2.100000e+00          2.100000e+00
# ...

# %%
test_info.head()
# Out:
#                            CUST_UID AGN_CNT_RCT_12_MON ICO_CUR_MON_ACM_TRX_TM  \
# 0  deca9c4409e84344bc4059116902ba0e              23662                      ?
# 1  25377f79cf9d4964a2f9893dc572caba                  ?                      2
# 2  66979a1614fb49f1bcdcdce75d6abefc               1672                      2
# 3  84142dedb7e0442eb9aa7aeadf93f66e               5432                    102
# 4  5e5817f15c8d4bdebefa820961854ac2              11842                    782
#
#   NB_RCT_3_MON_LGN_TMS_AGV AGN_CUR_YEAR_AMT AGN_CUR_YEAR_WAG_AMT  \
# 0                        ?                ?                    ?
# 1                        ?                ?                    ?
# 2                     48.7         992125.6                    ?
# 3                     88.7       46729796.3           46729796.3
# 4                   1545.3       27085791.9                    ?
#
#   AGN_AGR_LATEST_AGN_AMT ICO_CUR_MON_ACM_TRX_AMT COUNTER_CUR_YEAR_CNT_AMT  \
# ...

# %%
test_info.replace({'?':None},inplace =True)
test_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 50 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CUST_UID                                 12000 non-null  object
#  1   AGN_CNT_RCT_12_MON                       5559 non-null   float64
#  2   ICO_CUR_MON_ACM_TRX_TM                   10977 non-null  float64
#  3   NB_RCT_3_MON_LGN_TMS_AGV                 10897 non-null  float64
#  4   AGN_CUR_YEAR_AMT                         5221 non-null   float64
#  5   AGN_CUR_YEAR_WAG_AMT                     3583 non-null   float64
#  6   AGN_AGR_LATEST_AGN_AMT                   6105 non-null   float64
#  7   ICO_CUR_MON_ACM_TRX_AMT                  10977 non-null  float64
#  8   COUNTER_CUR_YEAR_CNT_AMT                 11699 non-null  float64
#  9   PUB_TO_PRV_TRX_AMT_CUR_YEAR              11699 non-null  float64
# ...

# %%
test_info.head()
# Out:
#                            CUST_UID  AGN_CNT_RCT_12_MON  \
# 0  deca9c4409e84344bc4059116902ba0e             23662.0
# 1  25377f79cf9d4964a2f9893dc572caba                 NaN
# 2  66979a1614fb49f1bcdcdce75d6abefc              1672.0
# 3  84142dedb7e0442eb9aa7aeadf93f66e              5432.0
# 4  5e5817f15c8d4bdebefa820961854ac2             11842.0
#
#    ICO_CUR_MON_ACM_TRX_TM  NB_RCT_3_MON_LGN_TMS_AGV  AGN_CUR_YEAR_AMT  \
# 0                     NaN                       NaN               NaN
# 1                     2.0                       NaN               NaN
# 2                     2.0                      48.7          992125.6
# 3                   102.0                      88.7        46729796.3
# 4                   782.0                    1545.3        27085791.9
#
#    AGN_CUR_YEAR_WAG_AMT  AGN_AGR_LATEST_AGN_AMT  ICO_CUR_MON_ACM_TRX_AMT  \
# 0                   NaN                135692.0                      NaN
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

#[MON_12_CUST_CNT_PTY_ID,WTHR_OPN_ONL_ICO,LGP_HLD_CARD_LVL,NB_CTC_HLD_IDV_AIO_CARD_SITU]
#LabelEncoder.fit(np.unique(train2.NB_CTC_HLD_IDV_AIO_CARD_SITU))
train_info[['MON_12_CUST_CNT_PTY_ID','WTHR_OPN_ONL_ICO','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']]=train_info[['MON_12_CUST_CNT_PTY_ID','WTHR_OPN_ONL_ICO','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']].apply(LabelEncoder().fit_transform)
train_info.head()
test_info[['MON_12_CUST_CNT_PTY_ID','WTHR_OPN_ONL_ICO','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']]=test_info[['MON_12_CUST_CNT_PTY_ID','WTHR_OPN_ONL_ICO','LGP_HLD_CARD_LVL','NB_CTC_HLD_IDV_AIO_CARD_SITU']].apply(LabelEncoder().fit_transform)
test_info.head()
# Out:
#                            CUST_UID  AGN_CNT_RCT_12_MON  \
# 0  deca9c4409e84344bc4059116902ba0e             23662.0
# 1  25377f79cf9d4964a2f9893dc572caba                 NaN
# 2  66979a1614fb49f1bcdcdce75d6abefc              1672.0
# 3  84142dedb7e0442eb9aa7aeadf93f66e              5432.0
# 4  5e5817f15c8d4bdebefa820961854ac2             11842.0
#
#    ICO_CUR_MON_ACM_TRX_TM  NB_RCT_3_MON_LGN_TMS_AGV  AGN_CUR_YEAR_AMT  \
# 0                     NaN                       NaN               NaN
# 1                     2.0                       NaN               NaN
# 2                     2.0                      48.7          992125.6
# 3                   102.0                      88.7        46729796.3
# 4                   782.0                    1545.3        27085791.9
#
#    AGN_CUR_YEAR_WAG_AMT  AGN_AGR_LATEST_AGN_AMT  ICO_CUR_MON_ACM_TRX_AMT  \
# 0                   NaN                135692.0                      NaN
# ...

# %%
train_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 51 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CUST_UID                                 40000 non-null  object
#  1   LABEL                                    40000 non-null  int64
#  2   AGN_CNT_RCT_12_MON                       18592 non-null  float64
#  3   ICO_CUR_MON_ACM_TRX_TM                   36497 non-null  float64
#  4   NB_RCT_3_MON_LGN_TMS_AGV                 36185 non-null  float64
#  5   AGN_CUR_YEAR_AMT                         17459 non-null  float64
#  6   AGN_CUR_YEAR_WAG_AMT                     12015 non-null  float64
#  7   AGN_AGR_LATEST_AGN_AMT                   20407 non-null  float64
#  8   ICO_CUR_MON_ACM_TRX_AMT                  36497 non-null  float64
#  9   COUNTER_CUR_YEAR_CNT_AMT                 39054 non-null  float64
# ...

# %%
train_info.to_csv('./data/original_train.csv',index=None)
test_info.to_csv('./data/original_test_A.csv',index=None)

# %%
['AGN_CUR_YEAR_AMT', 'AGN_CUR_YEAR_WAG_AMT', 'AGN_AGR_LATEST_AGN_AMT',
'MON_12_EXT_SAM_NM_TRSF_OUT_CNT','MON_12_EXT_SAM_AMT','MON_12_CUST_CNT_PTY_ID'
,'CUR_MON_COR_DPS_MON_DAY_AVG_BAL','CUR_YEAR_COR_DMND_DPS_DAY_AVG_BAL',
'CUR_YEAR_COR_DPS_YEAR_DAY_AVG_INCR','LAST_12_MON_MON_AVG_TRX_AMT_NAV','LAST_12_MON_DIF_NM_MON_AVG_TRX_AMT_NAV',
'EMP_NBR']

#分桶后只有一列
['ICO_CUR_MON_ACM_TRX_AMT','COUNTER_CUR_YEAR_CNT_AMT','PUB_TO_PRV_TRX_AMT_CUR_YEAR'
,'MON_12_EXT_SAM_TRSF_IN_AMT', 'MON_12_EXT_SAM_TRSF_OUT_AMT','CUR_MON_EXT_SAM_CUST_TRSF_IN_AMT'
,'CUR_MON_EXT_SAM_CUST_TRSF_OUT_AMT', 'CUR_YEAR_COUNTER_ENCASH_CNT','CUR_YEAR_MIN_BUS_INC',
,'HLD_FGN_CCY_ACT_NBR']

#没数据
['LAST_12_MON_COR_DPS_TM_PNT_BAL_PEAK_VAL','LAST_12_MON_COR_DPS_DAY_AVG_BAL','REG_CPT']
